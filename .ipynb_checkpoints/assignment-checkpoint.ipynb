# %% [markdown]
# # ASR Assignment 2024-25
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](https://www.inf.ed.ac.uk/teaching/courses/asr/coursework-2025.html).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/yiwang454/asr_labs/blob/main/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst
import math
import time
from collections import Counter
import heapq
from collections import deque

# ... (add your code to create WFSTs and Viterbi Decoder)

# %%
class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    PRUNE_THRESH_VAL = 80
    
    IS_PRUNING = False
    
    IS_EXP_7 = False
    
    TOTAL_STEPS = 0
    
    
    def __init__(self, f, audio_file_name):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                    self.TOTAL_STEPS +=1
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                #if self.V[t-1][i] >= self.PRUNE_THRESHOLD * self.BEST_PROB:

                for arc in self.f.arcs(i):

                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        self.TOTAL_STEPS +=1
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            
                            self.V[t][j] = prob
                            self.B[t][j] = i

                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
        
    def forward_step_exp_7(self, t):
        active_states = [(self.V[t-1][i], i) for i in self.f.states() if self.V[t-1][i] != self.NLL_ZERO]
        heapq.heapify(active_states) 

        obs_cache = {} 

        while active_states:
            _, i = heapq.heappop(active_states) 

            for arc in self.f.arcs(i):
                if arc.ilabel != 0:  # Skip epsilon arcs
                    self.TOTAL_STEPS +=1
                    j = arc.nextstate
                    tp = float(arc.weight)  # Transition probability

                    
                    if arc.ilabel not in obs_cache:
                        obs_cache[arc.ilabel] = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)

                    ep = obs_cache[arc.ilabel]
                    prob = tp + ep + self.V[t-1][i]

                    if prob < self.V[t][j]:
                        self.V[t][j] = prob
                        self.B[t][j] = i

                        if arc.olabel != 0:
                            self.W[t][j] = [arc.olabel]
                        else:
                            self.W[t][j] = []                        
        
        
    def finalise_decoding(self):
            """ this incorporates the probability of terminating at each state
            """

            best_final_cost = self.NLL_ZERO
            best_final_state = -1

            for state in self.f.states():
                final_weight = float(self.f.final(state))

                if self.V[-1][state] != self.NLL_ZERO:
                    if final_weight != math.inf:
                        self.V[-1][state] += final_weight

                    # Track the best final state
                    if self.V[-1][state] < best_final_cost:
                        best_final_cost = self.V[-1][state]
                        best_final_state = state

            # Fallback: if no final state was reached, use the best available path
            if best_final_state == -1:
                # Pick the lowest-cost path even if it doesn't end at a final state
                best_final_state = min(
                    range(len(self.V[-1])), key=lambda x: self.V[-1][x]
                )

            # Handle case where no path made it to the end
            if self.V[-1][best_final_state] >= self.NLL_ZERO:
                print("No path reached a valid final state. Using best available path.")
        
        
    def decode(self, bigrams):
        start = time.perf_counter()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            
            if self.IS_EXP_7:
                self.forward_step_exp_7(t)
            else:
                self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            if self.IS_PRUNING:
                self.pruning(t) #comment out if you want to stop pruning
            t += 1
        self.finalise_decoding()
        
        end = time.perf_counter()
        elapsed = end - start
        
        return elapsed
    
    #prune function which takes in T and checks the current self.V[t]
    def pruning(self, t):
        current_V = self.V[t] #get the list of states at this timestate
        min_V = min(current_V)
        if min_V == self.NLL_ZERO: #dont prune yet if the minimum V is infinite bc it means the V hasnt been populated
            return
        prune_thresh = min_V + self.PRUNE_THRESH_VAL
        for j in self.f.states():
            if current_V[j] > prune_thresh:
                self.V[t][j] = self.NLL_ZERO #set the current time and state vitrbi to be huge so the path is unlikely
    
    def backtrace(self):
        start = time.perf_counter()
        
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence = ' '.join([self.f.output_symbols().find(label) for label in best_out_sequence])
        #convert out_sequence to words from the phonesdef convert_phones_to_words(phone_sequence, phone_to_word):
        temp_phones = []
        word_sequence = []
        
        for phone in best_out_sequence.split(" "):
            temp_phones.append(phone)
            
            for word, phones in lex.items():
                if phones == temp_phones:
                    if word != "<sil>":
                        word_sequence.append(word)
                    temp_phones.clear()
        word_sequence = " ".join(word_sequence)
        
        end = time.perf_counter()
        elapsed = end - start
        
        return (best_state_sequence, word_sequence, elapsed)

# %%
def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    IS_SILENCE = False #NEED TO SET TRUE FOR SILENCE
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    if IS_SILENCE:
            lex["<sil>"] = ["sil"]
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
# state_table.write_text('tmp.txt')
# print(open('tmp.txt').read())

def generate_phone_wfst(f, start_state, phone, n):
    """
    Generate a WFST representating an n-state left-to-right phone HMM
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assmed to exist already
        phone (str): the phone label 
        n (int): number of states for each phone HMMectly modified i
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
        
        in_label = state_table.find('{}_{}'.format(phone, i))
        
        sl_weight = fst.Weight('log', -math.log(0.1))  # weight for self-loop
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        if i == n:
            out_label = phone_table.find(phone)
        else:
            out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(0.9)) # weight to next state
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
        
    return current_state

# %%
# Load words from lexicon
word_list = []
with open("lexicon.txt", "r") as lexicon:
    for line in lexicon:
        word = line.split()[0].lower()  # Extract only the first word
        word_list.append(word)

# Count word occurrences
word_counts = Counter(word_list)

# Total number of words
total_words = sum(word_counts.values())

# Compute unigram probabilities
word_probs = {word: count / total_words for word, count in word_counts.items()}

# Print top words
# for word, prob in sorted(word_probs.items(), key=lambda x: x[1], reverse=True):
#     print(f"{word}: {prob:.5f}")

# %%
def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription

all_transcription = []

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'): 
    ts = read_transcription(wav_file)
    all_transcription.append(ts)
    
#print(all_transcription)    


def build_bigram_model_backoff(corpus):
    bigram_model = {}
    unigram_counts = Counter()
    IS_NORMALISE = False
    for sentence in corpus:
        words = sentence.split()
        for word in words:
            unigram_counts[word] += 1
        for i in range(len(words) - 1):
            if words[i] not in bigram_model:
                bigram_model[words[i]] = Counter()
            bigram_model[words[i]][words[i+1]] += 1
    
    total_unigrams = sum(unigram_counts.values())
    unigram_probs = {word: count / total_unigrams for word, count in unigram_counts.items()}
    
    # Convert counts to probabilities with backoff
    for word, following in bigram_model.items():
        total_count = sum(following.values())
        prob_dist = {}

        for next_word, count in following.items():
            prob_dist[next_word] = (count / total_count) * 0.95
            prob_dist["<sil>"] = 1/11 * 0.95
        # Backoff to unigram probability scaled by 0.05
        for next_word, prob in unigram_probs.items():
            if next_word not in prob_dist:
                prob_dist[next_word] = prob * 0.05

        # Normalise the probabilities to sum to 1
        total_prob = sum(prob_dist.values())
        if IS_NORMALISE:
            bigram_model[word] = {k: v / total_prob for k, v in prob_dist.items()}
        else: return prob_dist

    # Adding silence transition probabilities
    words = list(bigram_model.keys())
    silence_prob = 1 / (len(words) + 1)  # +1 for <sil>
    bigram_model["<sil>"] = {word: silence_prob for word in words}
    bigram_model["<sil>"]["<sil>"] = silence_prob

    return bigram_model


def verify_probabilities(bigram_model):
    for word, transitions in bigram_model.items():
        total_prob = sum(transitions.values())
        if not (0.999 <= total_prob <= 1.001):  # Allowing small floating-point errors
            print(f"Warning: Probabilities for '{word}' sum to {total_prob}, not 1")
        else:
            print(f"'{word}' probabilities sum correctly to {total_prob}")


# bigrams = build_bigram_model_backoff(all_transcription)
# verify_probabilities(bigrams)
# print(bigrams["a"].keys())

# %%
# def build_bigram_model(corpus):
#     bigram_model = {}
    
#     #bigrams store P(X | Y) as Y:{X:0.5, Z:0.5}
    
#     for sentence in corpus:
#         words = sentence.split()
#         for i in range(len(words) - 1):
#             if words[i] not in bigram_model:
#                 bigram_model[words[i]] = Counter()
#             bigram_model[words[i]][words[i+1]] += 1
    
#     # Convert counts to probabilities
#     for word, following in bigram_model.items():
#         total_count = sum(following.values())
#         bigram_model[word] = {next_word: -math.log((count / total_count)*(10/11)) for next_word, count in following.items()}
#         bigram_model[word].update({"<sil>": -math.log(1/11)})
    
#     #instead of making a silence dictionary within bigram, we use the last actual word to inform the weight of the next arc
#     #this doesnt work for moving to silence as we need to have a probability
#     return bigram_model

# %%
def create_wfst(bigram):
    """ generate a HMM to recognise any single word sequence for words in the lexicon
    
    Args:
        n (int): states per phone HMM

    Returns:
        the constructed WFST
    
    """
    
    BIGRAM_THRESHOLD = 0.1
    
    IS_BIGRAM = False
    
    IS_BIGRAM_THRESH = False
    
    IS_SILENCE = False
    
    f = fst.Fst('log')
    n = 3
    f.set_input_symbols(state_table)
    f.set_output_symbols(phone_table)
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)

    f_weight = fst.Weight('log', -math.log(1)) #no penalising
    if IS_SILENCE:
        start_weight = fst.Weight('log', -math.log(1/11))
    else:
        start_weight = fst.Weight('log', -math.log(1/10))
    first_states = []
    final_states = []
    for word, phones in lex.items():
        current_state = f.add_state()
        first_states.append((current_state, word))
        
        f.add_arc(start_state, fst.Arc(0, 0, start_weight, current_state))
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        f.set_final(current_state)
        
        f.add_arc(current_state, fst.Arc(0, 0, f_weight, start_state))
        
        final_states.append((current_state, word))
    if IS_BIGRAM:    
        for current_state, current_word in final_states:
#             print(current_word)
            for next_state, next_word in first_states:
                if bigram[current_word][next_word] > BIGRAM_THRESHOLD or not IS_BIGRAM_THRESH:
#                     print(next_word)
#                     print(bigram[current_word][next_word])    
                    f.add_arc(current_state, fst.Arc(0, 0, fst.Weight('log', -math.log(bigram[current_word][next_word])), next_state)) 

    return f
bigrams = build_bigram_model_backoff(all_transcription)
f = create_wfst(bigrams)
f = fst.determinize(f)
from subprocess import check_call
from IPython.display import Image
f.draw('tmp.dot', portrait=True)
check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
Image(filename='tmp.png')

# %%
#with open("Task 2 silence test.txt", "w") as file:

#RUN INSTRUCTIONS: TO USE DIFFERENT VALUES FOR SELF LOOP AND TRANSITION, SEE "sl_weight" AND "next_weight" IN GENERATE_PHONE
#                  TO USE SILENCE -> SET IS_SILENCE IN PARSE_LEXICON AND CREATE_WFST TO TRUE
#                  TO USE PRUNING -> SET IS_PRUNING IN VITERBI DECODER TO TRUE (SILENCE MUST ALSO BE TRUE)
#                  TO USE BIGRAMS -> SET IS_BIGRAM IN CREATE_WFST() TO TRUE (SILENCE MUST ALSO BE TRUE)
#                  TO USE BIGRAM THRESHOLD -> SET IS_BIGRAM_THRESH IN CREATE_WFST() TO TRUE (ALL PREVIOUS MUST BE TRUE)
#                  TO USE NORMALISING -> SET IS_NORMALISE IN BIGRAM_MODEL_BACKOFF() TO TRUE
#                  TO USE VITERBI IMPROVEMENT -> SET IS_EXP_7 TO TRUE
# the above instructions should provide the ability to run the experiments, however this was added in
# post after experiments had been run, and may not give the exact results shown in the coursework document.
# if so, we apologise,
# s2206268, s2214984
with open("Task 4 VITERBI TEST.txt", "w") as file:
    bigram = build_bigram_model_backoff(all_transcription)
    f = create_wfst(bigram)
    
#     print(f)
    #f = fst.determinize(f) #COMMENT BACK IN TO DETERMINISE
    state_count = 0
    arc_count = 0
    for state in f.states():
        state_count += 1
        arc_count += len([arc for arc in f.arcs(state)])

        
    
        
    print(f'State Count: {state_count}, \nArc Count: {arc_count} \n')
    file.write(f"State Count: {state_count}, Arc Count: {arc_count} \n")


    for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                               # audio files

        decoder = MyViterbiDecoder(f, wav_file)

        decode_time = decoder.decode(bigram)
        decode_steps = decoder.TOTAL_STEPS
        (state_path, words, backtrace_time) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
                                                   # to return the words along the best path

        transcription = read_transcription(wav_file)
        error_counts = wer.compute_alignment_errors(transcription, words)
        word_count = len(transcription.split())

        word_error_rate = error_counts[0] + error_counts[1] + error_counts[2]

        word_error_rate = (word_error_rate/word_count)*100
        wav_file_name = wav_file.split("/")[-1]

        print(f'File: {wav_file_name}, \nErrors: {error_counts}, \nWER: {word_error_rate}, \nExpected: "{transcription}",\nactual: "{words}", \nSteps Taken: {decode_steps}, \nDecode Time: {decode_time}, \nBacktrace Time: {backtrace_time} \n')
        file.write(f'File: {wav_file_name}, \nErrors: {error_counts}, \nWER: {word_error_rate}, \nExpected: "{transcription}",\nActual: "{words}", \nSteps Taken: {decode_steps}, \nDecode Time: {decode_time}, \nBacktrace Time: {backtrace_time} \n')

print("\nDone")
        # you'll need to accumulate these to produce an overall Word Error Rate
# Out:
# State Count: 116,
# Arc Count: 230
#
# File: 0000.wav,
# Errors: (5, 0, 14),
# WER: 237.5,
# Expected: "peter piper pickled a peck of picked peppers",
# actual: "picked the the the where's of picked a of the of picked the pickled picked of picked of picked a of where's",
# Steps Taken: 172833,
# Decode Time: 5.362213991815224,
# Backtrace Time: 0.0024125240743160248
#
# File: 0001.wav,
# Errors: (3, 0, 17),
# WER: 333.33333333333337,
# Expected: "peter the piper of pickled peppers",
# actual: "picked picked the the the the of the piper picked the the pickled a where's where's picked the picked picked picked the the",
# Steps Taken: 200433,
# Decode Time: 5.841449592960998,
# Backtrace Time: 0.002779920818284154
#
# File: 0002.wav,
# Errors: (3, 0, 12),
# WER: 166.66666666666669,
# Expected: "picked piper peter peppers pickled of peck the where's",
# actual: "picked picked the picked a of peter picked picked the pickled where's pickled where's picked peck a the where's picked the",
# Steps Taken: 178813,
# Decode Time: 7.049500203924254,
# Backtrace Time: 0.0019409928936511278
#
# File: 0003.wav,
# Errors: (2, 0, 8),
# WER: 166.66666666666669,
# Expected: "peppers pickled peter a peck pickled",
# actual: "peck the the the picked where's pickled peter the of peck pickled picked the",
# Steps Taken: 110043,
# Decode Time: 3.4324179119430482,
# Backtrace Time: 0.0013011971022933722
#
# File: 0004.wav,
# Errors: (0, 0, 10),
# WER: 166.66666666666669,
# Expected: "piper peter picked a pickled piper",
# actual: "picked the the piper of peter picked a the of pickled piper of pickled picked the",
# Steps Taken: 96473,
# Decode Time: 3.017189438920468,
# Backtrace Time: 0.0008608880452811718
#
# File: 0005.wav,
# Errors: (2, 0, 8),
# WER: 142.85714285714286,
# Expected: "picked peppers pickled piper a the where's",
# actual: "peck the picked peck where's pickled piper pickled pickled the peter where's picked the the",
# Steps Taken: 137643,
# Decode Time: 4.297749676043168,
# Backtrace Time: 0.0019851638935506344
#
# File: 0006.wav,
# Errors: (2, 0, 5),
# WER: 116.66666666666667,
# Expected: "where's a peter pickled picked peppers",
# actual: "picked the where's of peter pickled picked peck of where's picked",
# Steps Taken: 96473,
# Decode Time: 3.0240269398782402,
# Backtrace Time: 0.0005023591220378876
#
# File: 0007.wav,
# Errors: (1, 0, 6),
# WER: 116.66666666666667,
# Expected: "peck pickled piper where's the peppers",
# actual: "picked the the peck pickled piper where's the peck where's the the",
# Steps Taken: 96473,
# Decode Time: 3.0049658101052046,
# Backtrace Time: 0.000506250187754631
#
# File: 0008.wav,
# Errors: (4, 0, 6),
# WER: 90.9090909090909,
# Expected: "picked of picked of peck of peter of peck peter pickled",
# actual: "picked the picked of a pickled peck of peck the pickled peck peck peter picked a a",
# Steps Taken: 82673,
# Decode Time: 2.5884705670177937,
# Backtrace Time: 0.001111919991672039
#
# File: 0009.wav,
# Errors: (1, 1, 9),
# WER: 122.22222222222223,
# Expected: "pickled of peppers pickled of peck pickled of peter",
# actual: "the the picked picked the a where's the of peppers pickled of peck a picked pickled of",
# Steps Taken: 86583,
# Decode Time: 3.289255575975403,
# Backtrace Time: 0.0005264659412205219
#
# File: 0010.wav,
# Errors: (7, 0, 4),
# WER: 137.5,
# Expected: "peter peck peck peppers of pickled peter peck",
# actual: "picked the the of piper piper the of where's of pickled of",
# Steps Taken: 67033,
# Decode Time: 2.071523291990161,
# Backtrace Time: 0.00039178086444735527
#
# File: 0011.wav,
# Errors: (4, 0, 9),
# WER: 118.18181818181819,
# Expected: "peter piper picked peter peppers peck peter pickled piper picked picked",
# actual: "picked the the pickled a the where's picked picked a the of peppers piper picked peter pickled piper picked picked",
# Steps Taken: 118093,
# Decode Time: 3.4579210781957954,
# Backtrace Time: 0.0007093539461493492
#
# File: 0012.wav,
# Errors: (0, 1, 7),
# WER: 160.0,
# Expected: "peter picked the pickled peppers",
# actual: "picked the picked of picked pickled peck of peppers picked the",
# Steps Taken: 74853,
# Decode Time: 2.291098315967247,
# Backtrace Time: 0.0004411789122968912
#
# File: 0013.wav,
# Errors: (1, 0, 7),
# WER: 133.33333333333331,
# Expected: "where's peter picked a peck piper",
# actual: "peck the where's peter picked the picked of peck piper of picked the",
# Steps Taken: 102223,
# Decode Time: 2.992344406200573,
# Backtrace Time: 0.0006279628723859787
#
# File: 0014.wav,
# Errors: (1, 0, 9),
# WER: 142.85714285714286,
# Expected: "picked a peck of pickled peppers peter",
# actual: "picked the the picked of peck of pickled peppers a peter picked picked the picked the",
# Steps Taken: 112113,
# Decode Time: 3.2788036949932575,
# Backtrace Time: 0.0006001607980579138
#
# File: 0015.wav,
# Errors: (1, 0, 9),
# WER: 142.85714285714286,
# Expected: "pickled peppers a peck where's peter piper",
# actual: "picked the pickled peppers of peck picked picked where's peter of piper picked the the the",
# Steps Taken: 116023,
# Decode Time: 3.382510163122788,
# Backtrace Time: 0.0006419778801500797
#
# File: 0016.wav,
# Errors: (4, 0, 9),
# WER: 162.5,
# Expected: "where's the peppers peter piper picked a peck",
# actual: "picked the the where's of peppers picked the picked of piper of picked peck picked the the",
# Steps Taken: 113953,
# Decode Time: 3.2883396081160754,
# Backtrace Time: 0.000604068161919713
#
# File: 0017.wav,
# Errors: (2, 0, 8),
# WER: 125.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "picked the the picked piper of picked of peck of picked pickled peppers peck the the",
# Steps Taken: 116023,
# Decode Time: 3.3887384349945933,
# Backtrace Time: 0.0015342219267040491
#
# File: 0018.wav,
# Errors: (2, 0, 6),
# WER: 88.88888888888889,
# Expected: "where's the peck of picked peppers peter piper picked",
# actual: "the where's the peck of picked peppers picked of piper the a the the the",
# Steps Taken: 118093,
# Decode Time: 3.4362116858828813,
# Backtrace Time: 0.0006069941446185112
#
# File: 0019.wav,
# Errors: (2, 0, 5),
# WER: 77.77777777777779,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "picked the where's the peck picked pickled peppers peck of piper picked the the",
# Steps Taken: 96473,
# Decode Time: 2.973194713005796,
# Backtrace Time: 0.000522351823747158
#
# File: 0020.wav,
# Errors: (1, 0, 11),
# WER: 150.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "picked the the peter of piper of picked picked of peck of of picked pickled peck peppers peck the",
# Steps Taken: 110043,
# Decode Time: 3.404160960810259,
# Backtrace Time: 0.0006124279461801052
#
# File: 0021.wav,
# Errors: (0, 1, 4),
# WER: 55.55555555555556,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "peck the where's the peck picked of peppers peter piper of picked",
# Steps Taken: 119933,
# Decode Time: 3.4671515789814293,
# Backtrace Time: 0.0006013261154294014
#
# File: 0022.wav,
# Errors: (1, 0, 8),
# WER: 225.0,
# Expected: "peter piper picked peppers",
# actual: "picked the picked of peter peck picked peck peppers picked the picked",
# Steps Taken: 82673,
# Decode Time: 2.3891375169623643,
# Backtrace Time: 0.0004649721086025238
#
# File: 0023.wav,
# Errors: (1, 0, 5),
# WER: 150.0,
# Expected: "peppers peter piper picked",
# actual: "picked the where's peter picked piper peck a picked",
# Steps Taken: 67033,
# Decode Time: 2.0601164440158755,
# Backtrace Time: 0.00037211389280855656
#
# File: 0024.wav,
# Errors: (1, 0, 4),
# WER: 125.0,
# Expected: "peter piper pickled peppers",
# actual: "peck the picked the piper pickled peck peppers",
# Steps Taken: 76693,
# Decode Time: 2.1820617408957332,
# Backtrace Time: 0.0010570669546723366
#
# File: 0025.wav,
# Errors: (1, 0, 6),
# WER: 100.0,
# Expected: "where's the pickled peppers peter piper pickled",
# actual: "picked the where's picked pickled peppers peter of piper pickled picked picked picked",
# Steps Taken: 104293,
# Decode Time: 2.9763302002102137,
# Backtrace Time: 0.000575090991333127
#
# File: 0026.wav,
# Errors: (2, 0, 21),
# WER: 135.29411764705884,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "picked picked picked picked picked peter picked piper peck a picked picked picked a peck of pickled peck where's picked the the where's the picked a peck of peck pickled picked picked where's peter piper picked a picked",
# Steps Taken: 202273,
# Decode Time: 5.873501954134554,
# Backtrace Time: 0.0012947989162057638
# File: 0027.wav,
# Errors: (2, 0, 6),
# WER: 266.66666666666663,
# Expected: "peter piper picked",
# actual: "picked the where's picked pickled peter a where's the",
# Steps Taken: 78763,
# Decode Time: 2.275926599977538,
# Backtrace Time: 0.0004264058079570532
#
# File: 0028.wav,
# Errors: (5, 0, 6),
# WER: 137.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "picked the picked picked picked picked piper peck pickled pickled of where's picked the",
# Steps Taken: 102223,
# Decode Time: 2.9372548810206354,
# Backtrace Time: 0.000576704042032361
#
# File: 0029.wav,
# Errors: (5, 0, 6),
# WER: 122.22222222222223,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "peck the where's peter pickled pickled peppers the of peter picked the the the the",
# Steps Taken: 131663,
# Decode Time: 3.79573402996175,
# Backtrace Time: 0.0006844541057944298
#
# File: 0030.wav,
# Errors: (1, 0, 10),
# WER: 366.66666666666663,
# Expected: "where's peter piper",
# actual: "picked pickled where's peter picked peter picked the the the picked picked the",
# Steps Taken: 86583,
# Decode Time: 2.489022829802707,
# Backtrace Time: 0.0004734180402010679
#
# File: 0031.wav,
# Errors: (5, 0, 7),
# WER: 200.0,
# Expected: "where's the peter peppers peppers a",
# actual: "picked pickled the where's of where's of picked where's picked where's piper the",
# Steps Taken: 108203,
# Decode Time: 3.120560048846528,
# Backtrace Time: 0.0005685761570930481
#
# File: 0032.wav,
# Errors: (3, 0, 11),
# WER: 233.33333333333334,
# Expected: "peck peter the peppers of piper",
# actual: "picked pickled a peck the where's picked where's the of piper picked picked the the the the",
# Steps Taken: 80603,
# Decode Time: 2.4119265561457723,
# Backtrace Time: 0.0012350149918347597
#
# File: 0033.wav,
# Errors: (4, 0, 8),
# WER: 171.42857142857142,
# Expected: "peter picked peter peppers where's the piper",
# actual: "peck the where's of picked where's of where's where's the picked the picked the the",
# Steps Taken: 84513,
# Decode Time: 2.6044039810076356,
# Backtrace Time: 0.00046739098615944386
#
# File: 0034.wav,
# Errors: (1, 0, 6),
# WER: 140.0,
# Expected: "peter where's the pickled peter",
# actual: "picked the peter picked where's picked pickled peter picked picked the",
# Steps Taken: 90493,
# Decode Time: 2.786156421992928,
# Backtrace Time: 0.0004912628792226315
#
# File: 0035.wav,
# Errors: (4, 0, 5),
# WER: 112.5,
# Expected: "peck the peppers peter where's the peck peck",
# actual: "picked the picked of where's where's where's of peck peck picked picked the",
# Steps Taken: 72783,
# Decode Time: 2.1100771019700915,
# Backtrace Time: 0.0004390229005366564
#
# File: 0036.wav,
# Errors: (1, 0, 3),
# WER: 66.66666666666666,
# Expected: "where's a peck of peter piper",
# actual: "picked the where's of peck of peter piper picked",
# Steps Taken: 70943,
# Decode Time: 2.218131654895842,
# Backtrace Time: 0.00037830392830073833
#
# File: 0037.wav,
# Errors: (0, 0, 7),
# WER: 140.0,
# Expected: "piper picked peppers peter pickled",
# actual: "picked the the piper picked picked peppers peter of pickled picked the",
# Steps Taken: 79453,
# Decode Time: 2.5325511239934713,
# Backtrace Time: 0.0004487971309572458
#
# File: 0038.wav,
# Errors: (1, 0, 5),
# WER: 150.0,
# Expected: "peter piper pickled peppers",
# actual: "picked the peter piper of pickled picked where's picked",
# Steps Taken: 68873,
# Decode Time: 2.162361809052527,
# Backtrace Time: 0.0005903190467506647
#
# File: 0039.wav,
# Errors: (2, 0, 5),
# WER: 175.0,
# Expected: "peppers picked a peter",
# actual: "picked the peck where's picked peck peter picked picked",
# Steps Taken: 58063,
# Decode Time: 1.7918157789390534,
# Backtrace Time: 0.0003681490197777748
#
# File: 0040.wav,
# Errors: (1, 0, 5),
# WER: 120.0,
# Expected: "pickled peck of pickled peppers",
# actual: "picked the pickled peck of pickled peck picked where's picked",
# Steps Taken: 79453,
# Decode Time: 2.3176936549134552,
# Backtrace Time: 0.0004305741749703884
#
# File: 0041.wav,
# Errors: (0, 0, 9),
# WER: 225.0,
# Expected: "where's pickled peter piper",
# actual: "picked pickled where's a where's peck pickled peck peter piper picked the the",
# Steps Taken: 76693,
# Decode Time: 2.3962842139881104,
# Backtrace Time: 0.0004497608169913292
#
# File: 0042.wav,
# Errors: (0, 0, 7),
# WER: 350.0,
# Expected: "where's peter",
# actual: "picked the the the where's peck peter pickled the",
# Steps Taken: 70943,
# Decode Time: 2.2095897630788386,
# Backtrace Time: 0.0003802888095378876
#
# File: 0043.wav,
# Errors: (1, 0, 11),
# WER: 240.0,
# Expected: "pickled peppers picked peter piper",
# actual: "picked the where's picked a pickled picked where's picked a picked peck peter piper picked the",
# Steps Taken: 108203,
# Decode Time: 3.3718215920962393,
# Backtrace Time: 0.0005932929925620556
#
# File: 0044.wav,
# Errors: (2, 0, 8),
# WER: 111.11111111111111,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "picked the pickled where's picked the peck pickled peck pickled peck of where's peter piper picked picked",
# Steps Taken: 119933,
# Decode Time: 3.7038435470312834,
# Backtrace Time: 0.0007666889578104019
#
# File: 0045.wav,
# Errors: (3, 0, 9),
# WER: 240.0,
# Expected: "a peck of pickled peppers",
# actual: "picked picked the of piper pickled peck a where's of piper where's picked the",
# Steps Taken: 90493,
# Decode Time: 2.7834851399529725,
# Backtrace Time: 0.000493078026920557
#
# File: 0046.wav,
# Errors: (8, 0, 13),
# WER: 123.52941176470588,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "picked the the where's of of picked the of a of pickled picked where's where's the of a of peck where's picked picked picked peter piper picked picked picked the",
# Steps Taken: 192613,
# Decode Time: 5.724125802051276,
# Backtrace Time: 0.0013655449729412794
#
# File: 0047.wav,
# Errors: (11, 0, 8),
# WER: 111.76470588235294,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "picked picked the peter of of of picked of of pickled pickled picked picked where's of picked pickled the where's picked of piper of peck",
# Steps Taken: 110043,
# Decode Time: 3.4381389659829438,
# Backtrace Time: 0.0007216781377792358
#
# File: 0048.wav,
# Errors: (6, 0, 23),
# WER: 170.58823529411765,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "a the the the where's picked the the of of of of picked picked the of of peck pickled of pickled picked where's where's the picked peck where's pickled picked where's peter picked piper of picked picked picked the the",
# Steps Taken: 263223,
# Decode Time: 8.144266763934866,
# Backtrace Time: 0.001500478945672512
#
# File: 0049.wav,
# Errors: (4, 0, 33),
# WER: 217.6470588235294,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "picked picked the peck pickled peck a of of of picked peck picked pickled where's picked the piper a peck the where's of picked pickled picked picked where's where's the of of picked piper a picked where's of picked pickled peppers picked peter picked piper of picked picked picked picked",
# Steps Taken: 280933,
# Decode Time: 8.188381117070094,
# Backtrace Time: 0.0017664071638137102
#
# File: 0050.wav,
# Errors: (7, 1, 10),
# WER: 105.88235294117648,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the picked the of of pickled of a pickled peck of picked where's where's of peck of picked pickled picked picked the of pickled picked picked",
# Steps Taken: 133733,
# Decode Time: 4.102060310076922,
# Backtrace Time: 0.0008408469147980213
#
# File: 0051.wav,
# Errors: (3, 0, 7),
# WER: 125.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peck pickled picked picked a picked piper picked of peck of the pickled peck where's",
# Steps Taken: 82673,
# Decode Time: 2.5447193670552224,
# Backtrace Time: 0.0004909320268779993
#
# File: 0052.wav,
# Errors: (0, 0, 8),
# WER: 88.88888888888889,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "picked picked picked piper a where's the peck of of pickled peppers peter piper picked picked the",
# Steps Taken: 106133,
# Decode Time: 3.285774333169684,
# Backtrace Time: 0.0009112739935517311
# File: 0053.wav,
# Errors: (1, 0, 5),
# WER: 85.71428571428571,
# Expected: "peter picked piper peppers of the peck",
# actual: "picked picked picked peter picked piper peck where's of the peck picked",
# Steps Taken: 80603,
# Decode Time: 2.483844568952918,
# Backtrace Time: 0.00045083207078278065
#
# File: 0054.wav,
# Errors: (1, 0, 3),
# WER: 57.14285714285714,
# Expected: "where's a pickled the peppers peck of",
# actual: "picked the where's of pickled the peppers peck of picked",
# Steps Taken: 80603,
# Decode Time: 2.492847828892991,
# Backtrace Time: 0.0004257648251950741
#
# File: 0055.wav,
# Errors: (2, 0, 8),
# WER: 47.61904761904761,
# Expected: "peppers piper peter pickled peck of piper where's a the picked peter of piper peppers picked the a where's the peter",
# actual: "peck the peppers piper of peter peck pickled peck of piper picked where's of the picked peter of piper peppers picked the picked of where's the peter picked picked",
# Steps Taken: 210323,
# Decode Time: 6.254139943048358,
# Backtrace Time: 0.0022014030255377293
#
# File: 0056.wav,
# Errors: (0, 0, 6),
# WER: 150.0,
# Expected: "peter piper picked peppers",
# actual: "picked the picked the the peter piper picked peppers picked",
# Steps Taken: 90493,
# Decode Time: 2.7955942200496793,
# Backtrace Time: 0.0004777370486408472
#
# File: 0057.wav,
# Errors: (0, 0, 3),
# WER: 60.0,
# Expected: "where's the peck piper picked",
# actual: "a the where's the peck piper picked picked",
# Steps Taken: 90493,
# Decode Time: 2.712832781020552,
# Backtrace Time: 0.00042993598617613316
#
# File: 0058.wav,
# Errors: (1, 0, 8),
# WER: 225.0,
# Expected: "pickled peppers peter picked",
# actual: "the the the pickled peck peck where's peter picked picked picked the",
# Steps Taken: 86583,
# Decode Time: 2.6673672790639102,
# Backtrace Time: 0.0005130518693476915
#
# File: 0059.wav,
# Errors: (1, 0, 4),
# WER: 100.0,
# Expected: "a peck of pickled peppers",
# actual: "peck the the of peck of pickled peppers picked",
# Steps Taken: 68873,
# Decode Time: 2.1196904440876096,
# Backtrace Time: 0.00036678300239145756

# %%
print("Done")
#f = create_wfst(bigram)
#from subprocess import check_call
#from IPython.display import Image
#f.draw('tmp.dot', portrait=True)
#check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
#Image(filename='tmp.png')

# %%
#
