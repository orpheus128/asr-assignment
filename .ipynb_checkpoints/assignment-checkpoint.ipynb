# %% [markdown]
# # ASR Assignment 2024-25
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](https://www.inf.ed.ac.uk/teaching/courses/asr/coursework-2025.html).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/yiwang454/asr_labs/blob/main/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst
import math
import time
from collections import Counter

# ... (add your code to create WFSTs and Viterbi Decoder)

# %%
class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    
    def __init__(self, f, audio_file_name):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                for arc in self.f.arcs(i):
                    
                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            self.V[t][j] = prob
                            self.B[t][j] = i
                            
                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                            
    
    def finalise_decoding(self):
        """ this incorporates the probability of terminating at each state
        """
        
        for state in self.f.states():
            final_weight = float(self.f.final(state))
            if self.V[-1][state] != self.NLL_ZERO:
                if final_weight == math.inf:
                    self.V[-1][state] = self.NLL_ZERO  # effectively says that we can't end in this state
                else:
                    self.V[-1][state] += final_weight
                    
        # get a list of all states where there was a path ending with non-zero probability
        finished = [x for x in self.V[-1] if x < self.NLL_ZERO]
        if not finished:  # if empty
            print("No path got to the end of the observations.")
        
        
    def decode(self):
        start = time.perf_counter()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            t += 1
        self.finalise_decoding()
        
        end = time.perf_counter()
        elapsed = end - start
        
        return t, elapsed
    
    def backtrace(self):
        start = time.perf_counter()
        
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence = ' '.join([self.f.output_symbols().find(label) for label in best_out_sequence])
        #convert out_sequence to words from the phonesdef convert_phones_to_words(phone_sequence, phone_to_word):
        temp_phones = []
        word_sequence = []
        
        for phone in best_out_sequence.split(" "):
            temp_phones.append(phone)
            
            for word, phones in lex.items():
                if phones == temp_phones:
                    if word != "<sil>":
                        word_sequence.append(word)
                    temp_phones.clear()
        word_sequence = " ".join(word_sequence)
        
        end = time.perf_counter()
        elapsed = end - start
        
        return (best_state_sequence, word_sequence, elapsed)

# %%
def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    lex["<sil>"] = ["sil"]
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
# state_table.write_text('tmp.txt')
# print(open('tmp.txt').read())

def generate_phone_wfst(f, start_state, phone, n):
    """
    Generate a WFST representating an n-state left-to-right phone HMM
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assmed to exist already
        phone (str): the phone label 
        n (int): number of states for each phone HMM
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
        
        in_label = state_table.find('{}_{}'.format(phone, i))
        
        sl_weight = fst.Weight('log', -math.log(0.9))  # weight for self-loop
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        if i == n:
            out_label = phone_table.find(phone)
        else:
            out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(0.1)) # weight to next state
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
        
    return current_state

# %%
# Load words from lexicon
word_list = []
with open("lexicon.txt", "r") as lexicon:
    for line in lexicon:
        word = line.split()[0].lower()  # Extract only the first word
        word_list.append(word)

# Count word occurrences
word_counts = Counter(word_list)

# Total number of words
total_words = sum(word_counts.values())

# Compute unigram probabilities
word_probs = {word: count / total_words for word, count in word_counts.items()}

# Print top words
# for word, prob in sorted(word_probs.items(), key=lambda x: x[1], reverse=True):
#     print(f"{word}: {prob:.5f}")

# %%
def create_wfst():
    """ generate a HMM to recognise any single word sequence for words in the lexicon
    
    Args:
        n (int): states per phone HMM

    Returns:
        the constructed WFST
    
    """
    om = observation_model.ObservationModel()
    f = fst.Fst('log')
    n = 3
    f.set_input_symbols(state_table)
    f.set_output_symbols(phone_table)
    
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)
#     silence = f.add_state()
#     silence_to_start_weight = fst.Weight('log', -math.log(1))
#     f.add_arc(silence, fst.Arc(0, 0, silence_to_start_weight, start_state))
#     silence_weight = fst.Weight('log', -math.log(0.1))
    f_weight = fst.Weight('log', -math.log(1)) #when no silence, set final weight to -log(1)
    
    start_weight = fst.Weight('log', -math.log(1/11)) # start weight is 0.1 bc there are 10 words
    
    for word, phones in lex.items():
        current_state = f.add_state()
        #trans_weight = fst.Weight('log', -math.log(word_probs.get(word))) #change math.log(x) to word_probs.get(word) for unigram, number for otherwise
        f.add_arc(start_state, fst.Arc(0, 0, start_weight, current_state)) #change start weight to trans weight when changing the transition into the word
        
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        f.set_final(current_state)
        
        f.add_arc(current_state, fst.Arc(0, 0, f_weight, start_state))
#         f.add_arc(current_state, fst.Arc(0, 0, silence_weight, silence))
        
    return f

# %%
def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription


with open("Task 2 silence test.txt", "w") as file:
#with open("Task 2 start 0.1, final 0.5, silence 0.5, sl 0.9, trans 0.1.txt", "w") as file:
    f = create_wfst()
    from subprocess import check_call
    from IPython.display import Image
    f.draw('tmp.dot', portrait=True)
    check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
    Image(filename='tmp.png')

    state_count = 0
    arc_count = 0
    for state in f.states():
        state_count += 1
        arc_count += len([arc for arc in f.arcs(state)])

    print(f'State Count: {state_count}, \nArc Count: {arc_count} \n')
    file.write(f"State Count: {state_count}, Arc Count: {arc_count} \n")

    for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                               # audio files

        decoder = MyViterbiDecoder(f, wav_file)

        decode_steps, decode_time = decoder.decode()
        (state_path, words, backtrace_time) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
                                                   # to return the words along the best path

        transcription = read_transcription(wav_file)
        error_counts = wer.compute_alignment_errors(transcription, words)
        word_count = len(transcription.split())

        word_error_rate = error_counts[0] + error_counts[1] + error_counts[2]

        word_error_rate = (word_error_rate/word_count)*100
        wav_file_name = wav_file.split("/")[-1]

        print(f'File: {wav_file_name}, \nErrors: {error_counts}, \nWER: {word_error_rate}, \nExpected: "{transcription}",\nactual: "{words}", \nSteps Taken: {decode_steps}, \nDecode Time: {decode_time}, \nBacktrace Time: {backtrace_time} \n')
        file.write(f'File: {wav_file_name}, \nErrors: {error_counts}, \nWER: {word_error_rate}, \nExpected: "{transcription}",\nActual: "{words}", \nSteps Taken: {decode_steps}, \nDecode Time: {decode_time}, \nBacktrace Time: {backtrace_time} \n')

print("\nDone")
        # you'll need to accumulate these to produce an overall Word Error Rate
# Out:
# State Count: 120,
# Arc Count: 238
#
# File: 0000.wav,
# Errors: (5, 0, 2),
# WER: 87.5,
# Expected: "peter piper pickled a peck of picked peppers",
# actual: "where's of a of pickled of picked of picked where's",
# Steps Taken: 758,
# Decode Time: 1.6463091149926186,
# Backtrace Time: 0.00036492408253252506
#
# File: 0001.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "peter the piper of pickled peppers",
# actual: "peter the piper of a where's where's",
# Steps Taken: 878,
# Decode Time: 1.897730962955393,
# Backtrace Time: 0.00039972399827092886
#
# File: 0002.wav,
# Errors: (3, 0, 3),
# WER: 66.66666666666666,
# Expected: "picked piper peter peppers pickled of peck the where's",
# actual: "picked a of peter peck where's pickled where's peck a the where's",
# Steps Taken: 784,
# Decode Time: 1.6987285839859396,
# Backtrace Time: 0.0003966789226979017
#
# File: 0003.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peppers pickled peter a peck pickled",
# actual: "peppers pickled peter of peck pickled",
# Steps Taken: 485,
# Decode Time: 1.0539912410313264,
# Backtrace Time: 0.00028560194186866283
#
# File: 0004.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "piper peter picked a pickled piper",
# actual: "piper of the picked a pickled piper",
# Steps Taken: 426,
# Decode Time: 0.9073372470447794,
# Backtrace Time: 0.0002518020337447524
#
# File: 0005.wav,
# Errors: (3, 0, 0),
# WER: 42.857142857142854,
# Expected: "picked peppers pickled piper a the where's",
# actual: "picked peppers pickled pickled of peter where's",
# Steps Taken: 605,
# Decode Time: 1.3117284829495475,
# Backtrace Time: 0.0003315610811114311
#
# File: 0006.wav,
# Errors: (2, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's a peter pickled picked peppers",
# actual: "where's of peter pickled a peppers",
# Steps Taken: 426,
# Decode Time: 0.9363284499850124,
# Backtrace Time: 0.00027005700394511223
#
# File: 0007.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peck pickled piper where's the peppers",
# actual: "peck pickled piper where's the where's",
# Steps Taken: 426,
# Decode Time: 0.9245061259716749,
# Backtrace Time: 0.00023353192955255508
#
# File: 0008.wav,
# Errors: (3, 3, 0),
# WER: 54.54545454545454,
# Expected: "picked of picked of peck of peter of peck peter pickled",
# actual: "picked a peck of pickled peck peter a",
# Steps Taken: 366,
# Decode Time: 0.779771919013001,
# Backtrace Time: 0.00022034102585166693
#
# File: 0009.wav,
# Errors: (2, 0, 2),
# WER: 44.44444444444444,
# Expected: "pickled of peppers pickled of peck pickled of peter",
# actual: "the a the of peppers pickled of peck pickled of the",
# Steps Taken: 383,
# Decode Time: 0.8273961300728843,
# Backtrace Time: 0.0002435039496049285
#
# File: 0010.wav,
# Errors: (6, 1, 0),
# WER: 87.5,
# Expected: "peter peck peck peppers of pickled peter peck",
# actual: "the of piper the where's pickled a",
# Steps Taken: 298,
# Decode Time: 0.6441768090007827,
# Backtrace Time: 0.0001907149562612176
#
# File: 0011.wav,
# Errors: (7, 1, 1),
# WER: 81.81818181818183,
# Expected: "peter piper picked peter peppers peck peter pickled piper picked picked",
# actual: "pickled where's a a the where's a peter pickled piper a",
# Steps Taken: 520,
# Decode Time: 1.1249929749174044,
# Backtrace Time: 0.000299659906886518
#
# File: 0012.wav,
# Errors: (2, 1, 1),
# WER: 80.0,
# Expected: "peter picked the pickled peppers",
# actual: "picked of picked peck peppers",
# Steps Taken: 332,
# Decode Time: 0.7064692330313846,
# Backtrace Time: 0.0001855599693953991
#
# File: 0013.wav,
# Errors: (0, 1, 1),
# WER: 33.33333333333333,
# Expected: "where's peter picked a peck piper",
# actual: "where's peter picked peck piper of",
# Steps Taken: 451,
# Decode Time: 0.9621662009740248,
# Backtrace Time: 0.00025982095394283533
#
# File: 0014.wav,
# Errors: (2, 0, 0),
# WER: 28.57142857142857,
# Expected: "picked a peck of pickled peppers peter",
# actual: "picked of peck of peck peppers peter",
# Steps Taken: 494,
# Decode Time: 1.0535940090194345,
# Backtrace Time: 0.00028344104066491127
#
# File: 0015.wav,
# Errors: (1, 1, 1),
# WER: 42.857142857142854,
# Expected: "pickled peppers a peck where's peter piper",
# actual: "pickled peppers peck where's the of piper",
# Steps Taken: 511,
# Decode Time: 1.103935117018409,
# Backtrace Time: 0.0002900699619203806
#
# File: 0016.wav,
# Errors: (3, 1, 1),
# WER: 62.5,
# Expected: "where's the peppers peter piper picked a peck",
# actual: "where's peppers picked of piper of peck peck",
# Steps Taken: 502,
# Decode Time: 1.0892468779347837,
# Backtrace Time: 0.0003048010403290391
#
# File: 0017.wav,
# Errors: (1, 2, 1),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the piper of picked peck pickled peppers",
# Steps Taken: 511,
# Decode Time: 1.0910641350783408,
# Backtrace Time: 0.00028562499210238457
#
# File: 0018.wav,
# Errors: (2, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of picked peppers peter piper picked",
# actual: "where's the peck picked peppers picked piper a",
# Steps Taken: 520,
# Decode Time: 1.1247650500154123,
# Backtrace Time: 0.0002952530048787594
#
# File: 0019.wav,
# Errors: (3, 1, 0),
# WER: 44.44444444444444,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's the peck the peppers peck piper peck",
# Steps Taken: 426,
# Decode Time: 0.9206137000583112,
# Backtrace Time: 0.0002717819297686219
#
# File: 0020.wav,
# Errors: (0, 1, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked peck of pickled peppers",
# Steps Taken: 485,
# Decode Time: 1.038292260025628,
# Backtrace Time: 0.00029509991873055696
#
# File: 0021.wav,
# Errors: (2, 1, 1),
# WER: 44.44444444444444,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's the peck picked peppers peter piper of a",
# Steps Taken: 528,
# Decode Time: 1.1445630099624395,
# Backtrace Time: 0.00029968004673719406
#
# File: 0022.wav,
# Errors: (1, 0, 0),
# WER: 25.0,
# Expected: "peter piper picked peppers",
# actual: "peter peter picked peppers",
# Steps Taken: 366,
# Decode Time: 0.7956538619473577,
# Backtrace Time: 0.0002216349821537733
#
# File: 0023.wav,
# Errors: (2, 0, 1),
# WER: 75.0,
# Expected: "peppers peter piper picked",
# actual: "where's peter piper peck a",
# Steps Taken: 298,
# Decode Time: 0.6311022989684716,
# Backtrace Time: 0.0001724290195852518
#
# File: 0024.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter piper pickled peppers",
# actual: "the of piper pickled peppers",
# Steps Taken: 340,
# Decode Time: 0.7214737529866397,
# Backtrace Time: 0.00012770702596753836
#
# File: 0025.wav,
# Errors: (1, 1, 0),
# WER: 28.57142857142857,
# Expected: "where's the pickled peppers peter piper pickled",
# actual: "where's pickled peppers peter piper picked",
# Steps Taken: 460,
# Decode Time: 0.9784677730640396,
# Backtrace Time: 0.0002833210164681077
#
# File: 0026.wav,
# Errors: (5, 0, 3),
# WER: 47.05882352941176,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter piper peck a picked a of pickled peppers where's picked a of picked peppers peter piper picked a picked",
# Steps Taken: 886,
# Decode Time: 1.9195354140829295,
# Backtrace Time: 0.0006016509141772985
#
# File: 0027.wav,
# Errors: (1, 1, 2),
# WER: 133.33333333333331,
# Expected: "peter piper picked",
# actual: "the picked peter a",
# Steps Taken: 349,
# Decode Time: 0.7585956519469619,
# Backtrace Time: 0.00020767003297805786
#
# File: 0028.wav,
# Errors: (2, 4, 0),
# WER: 75.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the peck pickled where's",
# Steps Taken: 451,
# Decode Time: 0.9805798300076276,
# Backtrace Time: 0.0002510880585759878
#
# File: 0029.wav,
# Errors: (3, 2, 2),
# WER: 77.77777777777779,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "the where's peck pickled peppers the of peter the",
# Steps Taken: 579,
# Decode Time: 1.2400943730026484,
# Backtrace Time: 0.00034104997757822275
#
# File: 0030.wav,
# Errors: (0, 1, 1),
# WER: 66.66666666666666,
# Expected: "where's peter piper",
# actual: "pickled where's peter",
# Steps Taken: 383,
# Decode Time: 0.8119235549820587,
# Backtrace Time: 0.00022301007993519306
#
# File: 0031.wav,
# Errors: (5, 0, 1),
# WER: 100.0,
# Expected: "where's the peter peppers peppers a",
# actual: "where's of where's of where's where's piper",
# Steps Taken: 477,
# Decode Time: 1.036404654965736,
# Backtrace Time: 0.00027036794926971197
# File: 0032.wav,
# Errors: (3, 1, 0),
# WER: 66.66666666666666,
# Expected: "peck peter the peppers of piper",
# actual: "a the picked where's piper",
# Steps Taken: 357,
# Decode Time: 0.7724009909434244,
# Backtrace Time: 0.00021005503367632627
#
# File: 0033.wav,
# Errors: (4, 1, 1),
# WER: 85.71428571428571,
# Expected: "peter picked peter peppers where's the piper",
# actual: "picked a where's of where's where's picked",
# Steps Taken: 374,
# Decode Time: 0.8162896879948676,
# Backtrace Time: 0.0002245290670543909
#
# File: 0034.wav,
# Errors: (0, 1, 0),
# WER: 20.0,
# Expected: "peter where's the pickled peter",
# actual: "peter where's pickled peter",
# Steps Taken: 400,
# Decode Time: 0.8859284250065684,
# Backtrace Time: 0.00022837799042463303
#
# File: 0035.wav,
# Errors: (6, 1, 0),
# WER: 87.5,
# Expected: "peck the peppers peter where's the peck peck",
# actual: "picked of where's where's of a a",
# Steps Taken: 323,
# Decode Time: 0.6945976599818096,
# Backtrace Time: 0.0001979480730369687
#
# File: 0036.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "where's a peck of peter piper",
# actual: "where's of peck of peter piper of",
# Steps Taken: 315,
# Decode Time: 0.6704693179344758,
# Backtrace Time: 0.00019244500435888767
#
# File: 0037.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper picked peppers peter pickled",
# actual: "piper picked peppers peter pickled",
# Steps Taken: 352,
# Decode Time: 0.7491967940004542,
# Backtrace Time: 0.00020278501324355602
#
# File: 0038.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter piper pickled peppers",
# actual: "peter piper pickled peck where's",
# Steps Taken: 306,
# Decode Time: 0.6496189259923995,
# Backtrace Time: 0.00019251194316893816
#
# File: 0039.wav,
# Errors: (2, 0, 0),
# WER: 50.0,
# Expected: "peppers picked a peter",
# actual: "where's picked peck peter",
# Steps Taken: 259,
# Decode Time: 0.5615933260414749,
# Backtrace Time: 0.00015645299572497606
#
# File: 0040.wav,
# Errors: (1, 0, 1),
# WER: 40.0,
# Expected: "pickled peck of pickled peppers",
# actual: "pickled peck of pickled peck where's",
# Steps Taken: 352,
# Decode Time: 0.7631050680065528,
# Backtrace Time: 0.00022188702132552862
#
# File: 0041.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's pickled peter piper",
# actual: "where's pickled peter piper",
# Steps Taken: 340,
# Decode Time: 0.7402105970541015,
# Backtrace Time: 0.00020289304666221142
#
# File: 0042.wav,
# Errors: (0, 0, 1),
# WER: 50.0,
# Expected: "where's peter",
# actual: "the where's peter",
# Steps Taken: 315,
# Decode Time: 0.6748751079430804,
# Backtrace Time: 0.0001828889362514019
#
# File: 0043.wav,
# Errors: (3, 0, 2),
# WER: 100.0,
# Expected: "pickled peppers picked peter piper",
# actual: "the a picked where's a picked piper",
# Steps Taken: 477,
# Decode Time: 1.038539138971828,
# Backtrace Time: 0.00027661700733006
#
# File: 0044.wav,
# Errors: (2, 1, 3),
# WER: 66.66666666666666,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "pickled where's peck a of peck of where's peter piper picked",
# Steps Taken: 528,
# Decode Time: 1.149587620049715,
# Backtrace Time: 0.00032671308144927025
#
# File: 0045.wav,
# Errors: (3, 0, 4),
# WER: 140.0,
# Expected: "a peck of pickled peppers",
# actual: "the the piper peck a where's of of where's",
# Steps Taken: 400,
# Decode Time: 0.8732403480680659,
# Backtrace Time: 0.0002411950845271349
#
# File: 0046.wav,
# Errors: (7, 5, 0),
# WER: 70.58823529411765,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the where's of of a where's of a where's peter piper peck",
# Steps Taken: 844,
# Decode Time: 1.8269644379615784,
# Backtrace Time: 0.00044134201016277075
#
# File: 0047.wav,
# Errors: (6, 5, 2),
# WER: 76.47058823529412,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of a of picked where's peck pickled picked piper of peck",
# Steps Taken: 485,
# Decode Time: 1.0511731610167772,
# Backtrace Time: 0.00029994803480803967
#
# File: 0048.wav,
# Errors: (8, 0, 3),
# WER: 64.70588235294117,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of of of peck of pickled picked where's where's the peck where's pickled where's peter piper peck",
# Steps Taken: 1151,
# Decode Time: 2.517414381960407,
# Backtrace Time: 0.0006727291038259864
#
# File: 0049.wav,
# Errors: (3, 2, 6),
# WER: 64.70588235294117,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "picked a of peck of a pickled pickled picked where's where's the of a where's of pickled peppers peter piper peck",
# Steps Taken: 1228,
# Decode Time: 2.6792383709689602,
# Backtrace Time: 0.0007234590593725443
#
# File: 0050.wav,
# Errors: (7, 3, 3),
# WER: 76.47058823529412,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of a of peck of picked where's peck pickled picked picked the picked peck",
# Steps Taken: 588,
# Decode Time: 1.274137172033079,
# Backtrace Time: 0.0003722350811585784
#
# File: 0051.wav,
# Errors: (4, 0, 1),
# WER: 62.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "a piper peck of peck of pickled peck where's",
# Steps Taken: 366,
# Decode Time: 0.7745648319832981,
# Backtrace Time: 0.0002817719941958785
#
# File: 0052.wav,
# Errors: (3, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "peppers the peck of pickled peppers the piper peck",
# Steps Taken: 468,
# Decode Time: 1.0095381940482184,
# Backtrace Time: 0.00029300700407475233
#
# File: 0053.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked piper peppers of the peck",
# actual: "peter picked piper peppers of the peck",
# Steps Taken: 357,
# Decode Time: 0.7613553339615464,
# Backtrace Time: 0.0002090419875457883
#
# File: 0054.wav,
# Errors: (0, 1, 0),
# WER: 14.285714285714285,
# Expected: "where's a pickled the peppers peck of",
# actual: "where's pickled the peppers peck of",
# Steps Taken: 357,
# Decode Time: 0.7596904119709507,
# Backtrace Time: 0.00020886794663965702
#
# File: 0055.wav,
# Errors: (3, 0, 0),
# WER: 14.285714285714285,
# Expected: "peppers piper peter pickled peck of piper where's a the picked peter of piper peppers picked the a where's the peter",
# actual: "peppers piper peter pickled peck of piper where's of the peck peter of piper peppers picked the of where's the peter",
# Steps Taken: 921,
# Decode Time: 2.000723096076399,
# Backtrace Time: 0.0005809509893879294
#
# File: 0056.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter piper picked peppers",
# actual: "peter piper picked peppers",
# Steps Taken: 400,
# Decode Time: 0.8681517820805311,
# Backtrace Time: 0.00023963500279933214
#
# File: 0057.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck piper picked",
# actual: "where's the peck piper picked",
# Steps Taken: 400,
# Decode Time: 0.8863453189842403,
# Backtrace Time: 0.00025152298621833324
#
# File: 0058.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "pickled peppers peter picked",
# actual: "pickled peck where's peter picked",
# Steps Taken: 383,
# Decode Time: 0.830316049978137,
# Backtrace Time: 0.00021389499306678772
#
# File: 0059.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "a peck of pickled peppers",
# actual: "of peck of pickled peppers",
# Steps Taken: 306,
# Decode Time: 0.6678458789829165,
# Backtrace Time: 0.0001944319810718298
#
# File: 0060.wav,
# Errors: (0, 1, 0),
# WER: 25.0,
# Expected: "peter picked a peck",
# actual: "peter picked peck",
# Steps Taken: 340,
# Decode Time: 0.7356936420546845,
# Backtrace Time: 0.00018507905770093203
#
# File: 0061.wav,
# Errors: (8, 2, 1),
# WER: 64.70588235294117,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled of peck of pickled where's where's peck peck of pickled where's the of a peck",
# Steps Taken: 912,
# Decode Time: 1.9870407569687814,
# Backtrace Time: 0.0005373558960855007
#
# File: 0062.wav,
# Errors: (4, 0, 1),
# WER: 55.55555555555556,
# Expected: "peter picked peck peppers where's peck pickled peter picked",
# actual: "peter a peck peppers where's a pickled the of peck",
# Steps Taken: 707,
# Decode Time: 1.5337086900835857,
# Backtrace Time: 0.0003782960120588541
# File: 0063.wav,
# Errors: (5, 0, 3),
# WER: 133.33333333333331,
# Expected: "peter piper peter piper peter piper",
# actual: "the of peter of a picked the of a",
# Steps Taken: 340,
# Decode Time: 0.7394473169697449,
# Backtrace Time: 0.00021125597413629293
#
# File: 0064.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "pickled peppers pickled peck pickled peppers",
# actual: "pickled where's pickled peck the pickled where's",
# Steps Taken: 417,
# Decode Time: 0.906488417997025,
# Backtrace Time: 0.0002580629661679268
#
# File: 0065.wav,
# Errors: (5, 3, 0),
# WER: 100.0,
# Expected: "picked picked picked peck picked picked picked peppers",
# actual: "pickled a pickled pickled where's",
# Steps Taken: 409,
# Decode Time: 0.8852641949197277,
# Backtrace Time: 0.0002285779919475317
#
# File: 0066.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper pickled of peck peter",
# actual: "piper pickled of peck peter",
# Steps Taken: 392,
# Decode Time: 0.846181335975416,
# Backtrace Time: 0.00019511498976498842
#
# File: 0067.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter peter peppers peter peppers pickled",
# actual: "where's peter peter peppers peter peppers pickled",
# Steps Taken: 588,
# Decode Time: 1.259307705098763,
# Backtrace Time: 0.00032778107561171055
#
# File: 0068.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peck peck pickled pickled peter peppers piper",
# actual: "peck peck pickled pickled peter peppers piper",
# Steps Taken: 451,
# Decode Time: 0.9803096560062841,
# Backtrace Time: 0.0002802920062094927
#
# File: 0069.wav,
# Errors: (1, 2, 0),
# WER: 16.666666666666664,
# Expected: "where's peter the peppers pickled piper of a peck pickled peter piper peck peck of a peter piper",
# actual: "where's peter of peppers pickled piper of peck pickled peter piper peck peck of peter piper",
# Steps Taken: 861,
# Decode Time: 1.8657517140964046,
# Backtrace Time: 0.0005151720251888037
#
# File: 0070.wav,
# Errors: (1, 1, 0),
# WER: 25.0,
# Expected: "peppers of a pickled peppers peter where's piper",
# actual: "peppers of pickled peppers peter where's peck",
# Steps Taken: 417,
# Decode Time: 0.9027645660098642,
# Backtrace Time: 0.000271235010586679
#
# File: 0071.wav,
# Errors: (7, 1, 3),
# WER: 64.70588235294117,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter peck a pickled peck the pickled peck where's where's picked peck pickled pickled peppers the the peter picked",
# Steps Taken: 989,
# Decode Time: 2.1490157690132037,
# Backtrace Time: 0.0005975289968773723
#
# File: 0072.wav,
# Errors: (1, 1, 0),
# WER: 11.76470588235294,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter piper picked of peck of pickled peppers where's the peck pickled peppers peter piper picked",
# Steps Taken: 963,
# Decode Time: 2.0831233850913122,
# Backtrace Time: 0.0005602199817076325
#
# File: 0073.wav,
# Errors: (1, 2, 1),
# WER: 25.0,
# Expected: "peter piper picked a peck of pickled peppers peter piper picked a peck of pickled peppers",
# actual: "peter piper picked of pickled pickled peppers peter piper picked of peck of pickled peppers",
# Steps Taken: 997,
# Decode Time: 2.1788705920334905,
# Backtrace Time: 0.0005838200449943542
#
# File: 0074.wav,
# Errors: (2, 2, 0),
# WER: 22.22222222222222,
# Expected: "where's the peck of pickled peppers peter piper picked where's the peck of pickled peppers peter piper picked",
# actual: "where's the peck of pickled peppers picked picked where's the peck pickled peppers peter peter picked",
# Steps Taken: 1006,
# Decode Time: 2.1762619470246136,
# Backtrace Time: 0.0005869839806109667
#
# File: 0075.wav,
# Errors: (1, 6, 3),
# WER: 40.0,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked peter piper picked a peck of pickled peppers",
# actual: "pickled peter picked of pickled pickled peppers where's the pickled pickled peppers peter piper picked peter piper picked of pickled pickled peppers",
# Steps Taken: 1416,
# Decode Time: 3.0705940219340846,
# Backtrace Time: 0.0008748739492148161
#
# File: 0076.wav,
# Errors: (3, 0, 3),
# WER: 120.0,
# Expected: "peter piper picked pickled peppers",
# actual: "the picked piper the a pickled peter peck",
# Steps Taken: 779,
# Decode Time: 1.6834598829736933,
# Backtrace Time: 0.0003880138974636793
#
# File: 0077.wav,
# Errors: (1, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's peter piper",
# actual: "where's pickled piper",
# Steps Taken: 417,
# Decode Time: 0.8899864900158718,
# Backtrace Time: 0.00022811500821262598
#
# File: 0078.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter pickled a peck of peppers",
# actual: "the picked pickled of peck of peter",
# Steps Taken: 473,
# Decode Time: 1.0257369430037215,
# Backtrace Time: 0.00026292994152754545
#
# File: 0079.wav,
# Errors: (2, 1, 1),
# WER: 50.0,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "peck of pickled where's peter piper the a",
# Steps Taken: 603,
# Decode Time: 1.3081709839170799,
# Backtrace Time: 0.0003272860776633024
#
# File: 0080.wav,
# Errors: (3, 0, 2),
# WER: 55.55555555555556,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "the where's of peck of pickled peppers pickled piper a the",
# Steps Taken: 593,
# Decode Time: 1.2934798190835863,
# Backtrace Time: 0.00033301697112619877
#
# File: 0081.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter picked peppers",
# actual: "peter picked picked picked",
# Steps Taken: 268,
# Decode Time: 0.5654289509402588,
# Backtrace Time: 0.00017323694191873074
#
# File: 0082.wav,
# Errors: (3, 0, 1),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the of piper picked of piper of pickled peppers",
# Steps Taken: 613,
# Decode Time: 1.3311316799372435,
# Backtrace Time: 0.0003516189754009247
#
# File: 0083.wav,
# Errors: (2, 2, 1),
# WER: 55.55555555555556,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of pickled pickled of peter piper peck",
# Steps Taken: 485,
# Decode Time: 1.0356274610385299,
# Backtrace Time: 0.0003005110193043947
#
# File: 0084.wav,
# Errors: (2, 1, 2),
# WER: 62.5,
# Expected: "pickled peppers picked a peck of peter piper",
# actual: "pickled of where's a of pickled peter of piper",
# Steps Taken: 588,
# Decode Time: 1.2771333010168746,
# Backtrace Time: 0.00034365803003311157
#
# File: 0085.wav,
# Errors: (1, 2, 2),
# WER: 55.55555555555556,
# Expected: "where's the peck of peter piper pickled peppers picked",
# actual: "where's of pickled peter piper pickled peck where's picked",
# Steps Taken: 562,
# Decode Time: 1.2021272369893268,
# Backtrace Time: 0.00035490095615386963
#
# File: 0086.wav,
# Errors: (2, 1, 3),
# WER: 75.0,
# Expected: "peter peppers picked pickled peck of peter piper",
# actual: "peter of piper where's picked the pickled pickled peter piper",
# Steps Taken: 528,
# Decode Time: 1.147129692020826,
# Backtrace Time: 0.0003184910165145993
#
# File: 0087.wav,
# Errors: (3, 0, 1),
# WER: 80.0,
# Expected: "pickled piper picked pickled peter",
# actual: "picked piper peck the peter peter",
# Steps Taken: 409,
# Decode Time: 0.8847583630122244,
# Backtrace Time: 0.00024644704535603523
#
# File: 0088.wav,
# Errors: (3, 0, 1),
# WER: 57.14285714285714,
# Expected: "pickled peter picked piper picked a peck",
# actual: "picked peter a piper of a of peck",
# Steps Taken: 383,
# Decode Time: 0.8331207409501076,
# Backtrace Time: 0.00028827995993196964
#
# File: 0089.wav,
# Errors: (2, 0, 0),
# WER: 66.66666666666666,
# Expected: "where's the picked",
# actual: "where's of a",
# Steps Taken: 178,
# Decode Time: 0.372298700036481,
# Backtrace Time: 0.00011998799163848162
#
# File: 0090.wav,
# Errors: (4, 1, 0),
# WER: 100.0,
# Expected: "a pickled peck of peter",
# actual: "of picked a picked",
# Steps Taken: 204,
# Decode Time: 0.44309640396386385,
# Backtrace Time: 0.00013789499644190073
#
# File: 0091.wav,
# Errors: (4, 1, 1),
# WER: 85.71428571428571,
# Expected: "peter the piper picked a pickled peck",
# actual: "the picked piper the peter peter a",
# Steps Taken: 392,
# Decode Time: 0.85460138192866,
# Backtrace Time: 0.0002449009334668517
#
# File: 0092.wav,
# Errors: (5, 1, 5),
# WER: 100.0,
# Expected: "peter picked a peck of pickled peppers pickled peck the peppers",
# actual: "the peter of peck of the of a where's the pickled a the peck where's",
# Steps Taken: 818,
# Decode Time: 1.7861097450368106,
# Backtrace Time: 0.00047993194311857224
# File: 0093.wav,
# Errors: (1, 1, 2),
# WER: 80.0,
# Expected: "peter picked the pickled peppers",
# actual: "the peter the pickled peck where's",
# Steps Taken: 306,
# Decode Time: 0.6706120260059834,
# Backtrace Time: 0.00020941405091434717
#
# File: 0094.wav,
# Errors: (1, 1, 1),
# WER: 50.0,
# Expected: "a peck of peppers picked piper",
# actual: "peck of peck peppers peter piper",
# Steps Taken: 374,
# Decode Time: 0.8196804160252213,
# Backtrace Time: 0.00023450900334864855
#
# File: 0095.wav,
# Errors: (2, 0, 1),
# WER: 27.27272727272727,
# Expected: "where's the peck of pickled peppers a peck of pickled peppers",
# actual: "where's the peck of pickled where's a peck of pickled peter where's",
# Steps Taken: 588,
# Decode Time: 1.2854444339172915,
# Backtrace Time: 0.00035316101275384426
#
# File: 0096.wav,
# Errors: (2, 2, 0),
# WER: 80.0,
# Expected: "the peck of pickled peppers",
# actual: "of a of",
# Steps Taken: 383,
# Decode Time: 0.8218555089551955,
# Backtrace Time: 0.00019931001588702202
#
# File: 0097.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 357,
# Decode Time: 0.7589760239934549,
# Backtrace Time: 0.00021343608386814594
#
# File: 0098.wav,
# Errors: (0, 1, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper a peck of pickled peppers",
# Steps Taken: 588,
# Decode Time: 1.276303983060643,
# Backtrace Time: 0.0003291500033810735
#
# File: 0099.wav,
# Errors: (1, 0, 0),
# WER: 50.0,
# Expected: "piper picked",
# actual: "piper a",
# Steps Taken: 204,
# Decode Time: 0.42927029402926564,
# Backtrace Time: 0.00012632296420633793
#
# File: 0100.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter piper picked the peppers",
# actual: "peter piper a the peppers",
# Steps Taken: 485,
# Decode Time: 1.0370046370662749,
# Backtrace Time: 0.0002754349261522293
#
# File: 0101.wav,
# Errors: (0, 3, 0),
# WER: 27.27272727272727,
# Expected: "peter piper picked a peck of pickled peppers picked a peck",
# actual: "peter piper picked peck pickled peppers picked peck",
# Steps Taken: 468,
# Decode Time: 1.010568312020041,
# Backtrace Time: 0.00028968893457204103
#
# File: 0102.wav,
# Errors: (2, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's peck of picked peppers peter piper peck",
# Steps Taken: 366,
# Decode Time: 0.7883385219611228,
# Backtrace Time: 0.00023583893198519945
#
# File: 0103.wav,
# Errors: (7, 1, 0),
# WER: 80.0,
# Expected: "peter piper peter piper picked a peck of pickled peppers",
# actual: "picked of of of peter peck peck peck peppers",
# Steps Taken: 366,
# Decode Time: 0.7926744190044701,
# Backtrace Time: 0.000241192989051342
#
# File: 0104.wav,
# Errors: (4, 1, 1),
# WER: 66.66666666666666,
# Expected: "pickled peppers pickled peppers peter piper picked a peck",
# actual: "picked where's picked peck where's peter piper picked peck",
# Steps Taken: 366,
# Decode Time: 0.8022450460121036,
# Backtrace Time: 0.0002504789736121893
#
# File: 0105.wav,
# Errors: (2, 2, 0),
# WER: 40.0,
# Expected: "the peck of pickled peppers peter piper picked a peck",
# actual: "the peck of picked peppers picked picked peck",
# Steps Taken: 349,
# Decode Time: 0.7598459540167823,
# Backtrace Time: 0.00022877601440995932
#
# File: 0106.wav,
# Errors: (0, 1, 2),
# WER: 50.0,
# Expected: "piper picked a peck of peppers",
# actual: "piper a peck peck peck of peppers",
# Steps Taken: 468,
# Decode Time: 1.0100120200077072,
# Backtrace Time: 0.0002638041041791439
#
# File: 0107.wav,
# Errors: (0, 0, 1),
# WER: 50.0,
# Expected: "where's peter",
# actual: "where's peter a",
# Steps Taken: 349,
# Decode Time: 0.762023997027427,
# Backtrace Time: 0.0001912920270115137
#
# File: 0108.wav,
# Errors: (0, 1, 1),
# WER: 25.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper a picked peck of pickled peppers",
# Steps Taken: 528,
# Decode Time: 1.1572303229477257,
# Backtrace Time: 0.0003130839904770255
#
# File: 0109.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "pickled peppers peter piper picked",
# actual: "pickled peppers peter piper picked",
# Steps Taken: 434,
# Decode Time: 0.9256293519865721,
# Backtrace Time: 0.000249480945058167
#
# File: 0110.wav,
# Errors: (0, 0, 1),
# WER: 33.33333333333333,
# Expected: "peter picked piper",
# actual: "peter picked piper the",
# Steps Taken: 332,
# Decode Time: 0.7058122040471062,
# Backtrace Time: 0.00018480699509382248
#
# File: 0111.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter piper picked",
# actual: "peter piper of peck",
# Steps Taken: 298,
# Decode Time: 0.6419972979929298,
# Backtrace Time: 0.00017794605810195208
#
# File: 0112.wav,
# Errors: (0, 2, 1),
# WER: 60.0,
# Expected: "a peck of pickled peppers",
# actual: "of pickled pickled peppers",
# Steps Taken: 323,
# Decode Time: 0.6975970179773867,
# Backtrace Time: 0.0001983660040423274
#
# File: 0113.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck",
# actual: "where's the peck",
# Steps Taken: 178,
# Decode Time: 0.372622673981823,
# Backtrace Time: 0.00012198998592793941
#
# File: 0114.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "pickled peppers",
# actual: "pickled peppers",
# Steps Taken: 238,
# Decode Time: 0.5134254960576072,
# Backtrace Time: 0.00015505601186305285
#
# File: 0115.wav,
# Errors: (1, 0, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked of peck of pickled peppers",
# Steps Taken: 374,
# Decode Time: 0.8108942729886621,
# Backtrace Time: 0.000234988983720541
#
# File: 0116.wav,
# Errors: (1, 1, 0),
# WER: 28.57142857142857,
# Expected: "peter piper picked a peck of peppers",
# actual: "peter piper peter peck of peppers",
# Steps Taken: 417,
# Decode Time: 0.9024382859934121,
# Backtrace Time: 0.00024337403010576963
#
# File: 0117.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck peter piper picked",
# actual: "where's the peck peter piper picked",
# Steps Taken: 371,
# Decode Time: 0.818758295965381,
# Backtrace Time: 0.00022500893101096153
#
# File: 0118.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter piper picked pickled peppers",
# actual: "peter piper peter pickled peppers",
# Steps Taken: 445,
# Decode Time: 0.9702642540214583,
# Backtrace Time: 0.00028381997253745794
#
# File: 0119.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck of pickled peppers",
# actual: "where's the peck of pickled peppers",
# Steps Taken: 371,
# Decode Time: 0.8031322309980169,
# Backtrace Time: 0.00021193490829318762
#
# File: 0120.wav,
# Errors: (1, 1, 0),
# WER: 25.0,
# Expected: "the peck of pickled peppers peter piper picked",
# actual: "the peck pickled peppers peter piper peter",
# Steps Taken: 491,
# Decode Time: 1.0490247870329767,
# Backtrace Time: 0.000300870044156909
#
# File: 0121.wav,
# Errors: (2, 1, 0),
# WER: 60.0,
# Expected: "peter piper picked a peck",
# actual: "picked piper peck peck",
# Steps Taken: 323,
# Decode Time: 0.6868538958951831,
# Backtrace Time: 0.00018894800450652838
#
# File: 0122.wav,
# Errors: (2, 0, 0),
# WER: 33.33333333333333,
# Expected: "a peck of peppers peter picked",
# actual: "of peck of peppers peter peck",
# Steps Taken: 383,
# Decode Time: 0.8200772430282086,
# Backtrace Time: 0.00021864497102797031
#
# File: 0123.wav,
# Errors: (1, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the pickled peck peter picked",
# actual: "where's the pickled picked picked",
# Steps Taken: 357,
# Decode Time: 0.7590000299969688,
# Backtrace Time: 0.00020478595979511738
#
# File: 0124.wav,
# Errors: (4, 0, 1),
# WER: 62.5,
# Expected: "where's the peck of peppers peter piper picked",
# actual: "where's the peck of where's picked of of peck",
# Steps Taken: 434,
# Decode Time: 0.9237100830068812,
# Backtrace Time: 0.0002617640420794487
#
# File: 0125.wav,
# Errors: (1, 1, 0),
# WER: 40.0,
# Expected: "peter piper picked pickled peppers",
# actual: "picked picked pickled peppers",
# Steps Taken: 332,
# Decode Time: 0.7064119280548766,
# Backtrace Time: 0.00019864598289132118
#
# File: 0126.wav,
# Errors: (1, 1, 0),
# WER: 40.0,
# Expected: "peter picked a pickled peppers",
# actual: "pickled a pickled peppers",
# Steps Taken: 571,
# Decode Time: 1.2359486459754407,
# Backtrace Time: 0.00029448000714182854
#
# File: 0127.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter pickled a peck piper",
# actual: "peter pickled of peck piper",
# Steps Taken: 511,
# Decode Time: 1.1059210899984464,
# Backtrace Time: 0.00028529507108032703
# File: 0128.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "where's piper pickled picked the piper",
# actual: "where's piper of pickled a the piper",
# Steps Taken: 494,
# Decode Time: 1.0559305510250852,
# Backtrace Time: 0.00027906696777790785
#
# File: 0129.wav,
# Errors: (2, 1, 2),
# WER: 62.5,
# Expected: "picked of piper peter peppers where's peter piper",
# actual: "a piper of peter peck where's where's peter piper",
# Steps Taken: 562,
# Decode Time: 1.2204939350485802,
# Backtrace Time: 0.0003217580961063504
#
# File: 0130.wav,
# Errors: (3, 0, 2),
# WER: 83.33333333333334,
# Expected: "peppers picked picked pickled of pickled",
# actual: "the where's a a pickled of pickled a",
# Steps Taken: 648,
# Decode Time: 1.3994416519999504,
# Backtrace Time: 0.00034225103445351124
#
# File: 0131.wav,
# Errors: (2, 1, 1),
# WER: 44.44444444444444,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's peck of picked of peppers picked piper picked",
# Steps Taken: 537,
# Decode Time: 1.174054326955229,
# Backtrace Time: 0.00030795601196587086
#
# File: 0132.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 255,
# Decode Time: 0.5395634459564462,
# Backtrace Time: 0.00015609199181199074
#
# File: 0133.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "where's the peck peter piper picked",
# actual: "where's the peck peter peck picked",
# Steps Taken: 426,
# Decode Time: 0.9214221560396254,
# Backtrace Time: 0.00023995398078113794
#
# File: 0134.wav,
# Errors: (2, 0, 0),
# WER: 25.0,
# Expected: "picked a peck of pickled peppers where's peter",
# actual: "picked of peck of pickled where's where's peter",
# Steps Taken: 665,
# Decode Time: 1.4456307080108672,
# Backtrace Time: 0.0003469049697741866
#
# File: 0135.wav,
# Errors: (2, 0, 1),
# WER: 75.0,
# Expected: "peter pickled the peppers",
# actual: "peter picked the of where's",
# Steps Taken: 315,
# Decode Time: 0.6722075860016048,
# Backtrace Time: 0.00018679199274629354
#
# File: 0136.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "where's the peppers peter pickled",
# actual: "where's the where's peter pickled",
# Steps Taken: 349,
# Decode Time: 0.7420742129907012,
# Backtrace Time: 0.00019172299653291702
#
# File: 0137.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "piper picked the peck",
# actual: "piper of a the peck",
# Steps Taken: 366,
# Decode Time: 0.7801491529680789,
# Backtrace Time: 0.00020408490672707558
#
# File: 0138.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter picked the pickled peppers",
# actual: "the picked the pickled peppers",
# Steps Taken: 289,
# Decode Time: 0.6291407509706914,
# Backtrace Time: 0.00017489807214587927
#
# File: 0139.wav,
# Errors: (1, 2, 0),
# WER: 33.33333333333333,
# Expected: "where's the pickled peppers of the peck piper picked",
# actual: "where's pickled where's of peck piper picked",
# Steps Taken: 443,
# Decode Time: 0.9619527850300074,
# Backtrace Time: 0.00026613904628902674
#
# File: 0140.wav,
# Errors: (2, 0, 2),
# WER: 100.0,
# Expected: "peter piper pickled peppers",
# actual: "peck a picked of pickled peppers",
# Steps Taken: 296,
# Decode Time: 0.6405608459608629,
# Backtrace Time: 0.0001834249123930931
#
# File: 0141.wav,
# Errors: (4, 1, 0),
# WER: 71.42857142857143,
# Expected: "peter pickled a peck of pickled peppers",
# actual: "peppers the the peck of where's",
# Steps Taken: 445,
# Decode Time: 0.9678692199522629,
# Backtrace Time: 0.0002543210284784436
#
# File: 0142.wav,
# Errors: (2, 0, 1),
# WER: 37.5,
# Expected: "where's the peck of peppers peter piper pickled",
# actual: "where's the peck of of picked piper of pickled",
# Steps Taken: 417,
# Decode Time: 0.9018652630038559,
# Backtrace Time: 0.00026801403146237135
#
# File: 0143.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "picked peppers peter piper pickled",
# actual: "picked peppers peter piper pickled",
# Steps Taken: 361,
# Decode Time: 0.7824191169347614,
# Backtrace Time: 0.0002207320649176836
#
# File: 0144.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "where's the peter piper pickled peppers",
# actual: "where's the peter piper pickled where's",
# Steps Taken: 333,
# Decode Time: 0.7221851039212197,
# Backtrace Time: 0.00021063501480966806
#
# File: 0145.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peppers pickled of peck the where's",
# actual: "peppers pickled of piper the where's",
# Steps Taken: 357,
# Decode Time: 0.7724182249512523,
# Backtrace Time: 0.00019882002379745245
#
# File: 0146.wav,
# Errors: (0, 1, 0),
# WER: 25.0,
# Expected: "piper pickled a peck",
# actual: "piper pickled peck",
# Steps Taken: 264,
# Decode Time: 0.5566118709975854,
# Backtrace Time: 0.0001563740661367774
#
# File: 0147.wav,
# Errors: (0, 0, 2),
# WER: 66.66666666666666,
# Expected: "peter picked piper",
# actual: "peter of picked piper of",
# Steps Taken: 229,
# Decode Time: 0.4790156619856134,
# Backtrace Time: 0.00013059505727142096
#
# File: 0148.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the pickled peter piper",
# actual: "where's the pickled peter piper",
# Steps Taken: 349,
# Decode Time: 0.750095263007097,
# Backtrace Time: 0.0002031349577009678
#
# File: 0149.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "a peck of peter peppers",
# actual: "of peck of peter peppers",
# Steps Taken: 272,
# Decode Time: 0.5855437490390614,
# Backtrace Time: 0.00016743596643209457
#
# File: 0150.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper peter piper peter piper picked",
# actual: "piper peter piper peter piper picked",
# Steps Taken: 741,
# Decode Time: 1.6061852889833972,
# Backtrace Time: 0.00037436699494719505
#
# File: 0151.wav,
# Errors: (3, 0, 2),
# WER: 83.33333333333334,
# Expected: "of the pickled peppers piper picked",
# actual: "of picked pickled picked where's piper peck a",
# Steps Taken: 511,
# Decode Time: 1.1202988020377234,
# Backtrace Time: 0.00030540593434125185
#
# File: 0152.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 434,
# Decode Time: 0.9580435929819942,
# Backtrace Time: 0.00023871299345046282
#
# File: 0153.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "peppers pickled piper",
# actual: "peck where's pickled piper",
# Steps Taken: 417,
# Decode Time: 0.8942383899120614,
# Backtrace Time: 0.00023477699141949415
#
# File: 0154.wav,
# Errors: (3, 2, 1),
# WER: 54.54545454545454,
# Expected: "where's the peck of peter piper pickled peppers peter piper picked",
# actual: "where's pickled peter piper peck picked where's peter piper picked",
# Steps Taken: 605,
# Decode Time: 1.3151977229863405,
# Backtrace Time: 0.0003545759245753288
#
# File: 0155.wav,
# Errors: (1, 1, 1),
# WER: 30.0,
# Expected: "peter piper pickled peppers picked a peck where's the peck",
# actual: "the of piper pickled peppers picked peck where's the peck",
# Steps Taken: 408,
# Decode Time: 0.8814777469960973,
# Backtrace Time: 0.00027575797867029905
#
# File: 0156.wav,
# Errors: (2, 0, 0),
# WER: 25.0,
# Expected: "pickled a peck piper peppers picked where's peter",
# actual: "pickled the of piper peppers picked where's peter",
# Steps Taken: 398,
# Decode Time: 0.8589827029500157,
# Backtrace Time: 0.0002662119222804904
#
# File: 0157.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked peppers",
# actual: "peter picked peppers",
# Steps Taken: 222,
# Decode Time: 0.4625941750127822,
# Backtrace Time: 0.00013825297355651855
#
# File: 0158.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck of pickled peppers peter piper pickled peppers where's the picked peck",
# actual: "where's the peck of pickled peppers peter piper pickled peppers where's the picked peck",
# Steps Taken: 621,
# Decode Time: 1.342193037038669,
# Backtrace Time: 0.000384259968996048
#
# File: 0159.wav,
# Errors: (0, 0, 3),
# WER: 50.0,
# Expected: "pickled pickled pickled peppers peppers peck",
# actual: "the pickled pickled pickled the peppers peppers the peck",
# Steps Taken: 436,
# Decode Time: 0.9291612060042098,
# Backtrace Time: 0.0002915880177170038
#
# File: 0160.wav,
# Errors: (6, 1, 3),
# WER: 58.82352941176471,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled of picked peck of pickled of where's where's the peck of pickled picked the of picked of a",
# Steps Taken: 656,
# Decode Time: 1.4158551159780473,
# Backtrace Time: 0.0004287860356271267
# File: 0161.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter picked a peck of peppers",
# actual: "the of picked of peck of where's",
# Steps Taken: 357,
# Decode Time: 0.7703675329685211,
# Backtrace Time: 0.00020281306933611631
#
# File: 0162.wav,
# Errors: (2, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's the peppers peter piper picked",
# actual: "where's the peppers pickled piper a",
# Steps Taken: 349,
# Decode Time: 0.7578479490475729,
# Backtrace Time: 0.00020821497309952974
#
# File: 0163.wav,
# Errors: (3, 0, 0),
# WER: 42.857142857142854,
# Expected: "a peck of pickled peppers peter picked",
# actual: "of peck of pickled peppers pickled a",
# Steps Taken: 357,
# Decode Time: 0.7736837300471961,
# Backtrace Time: 0.0002269550459459424
#
# File: 0164.wav,
# Errors: (3, 0, 1),
# WER: 80.0,
# Expected: "pickled peppers picked peter piper",
# actual: "the of the picked picked piper",
# Steps Taken: 272,
# Decode Time: 0.5783833949826658,
# Backtrace Time: 0.0001742170425131917
#
# File: 0165.wav,
# Errors: (2, 2, 3),
# WER: 87.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the the piper picked of pickled pickled picked where's",
# Steps Taken: 989,
# Decode Time: 2.1590368119068444,
# Backtrace Time: 0.000498899957165122
#
# File: 0166.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter",
# actual: "peter",
# Steps Taken: 238,
# Decode Time: 0.5147540749749169,
# Backtrace Time: 0.00012199301272630692
#
# File: 0167.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper",
# actual: "piper",
# Steps Taken: 178,
# Decode Time: 0.37258448801003397,
# Backtrace Time: 0.0001088359858840704
#
# File: 0168.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peck",
# actual: "peck",
# Steps Taken: 170,
# Decode Time: 0.3693557089427486,
# Backtrace Time: 8.961709681898355e-05
#
# File: 0169.wav,
# Errors: (1, 0, 0),
# WER: 100.0,
# Expected: "pickled",
# actual: "peck",
# Steps Taken: 153,
# Decode Time: 0.3179366539698094,
# Backtrace Time: 9.366206359118223e-05
#
# File: 0170.wav,
# Errors: (1, 0, 0),
# WER: 100.0,
# Expected: "peppers",
# actual: "the",
# Steps Taken: 204,
# Decode Time: 0.43018273392226547,
# Backtrace Time: 0.00011101202107965946
#
# File: 0171.wav,
# Errors: (2, 3, 2),
# WER: 87.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the of of peter pickled peter peppers",
# Steps Taken: 361,
# Decode Time: 0.7691530730808154,
# Backtrace Time: 0.00022375292610377073
#
# File: 0172.wav,
# Errors: (4, 2, 1),
# WER: 77.77777777777779,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's pickled pickled peter peter peter pickled the",
# Steps Taken: 454,
# Decode Time: 0.9909560290398076,
# Backtrace Time: 0.0002903060521930456
#
# File: 0173.wav,
# Errors: (5, 0, 5),
# WER: 125.0,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "the of of of of pickled of of peter of of of the",
# Steps Taken: 454,
# Decode Time: 0.9922841410152614,
# Backtrace Time: 0.00026418198831379414
#
# File: 0174.wav,
# Errors: (5, 1, 3),
# WER: 100.0,
# Expected: "peter piper picked a peck where's the pickled peppers",
# actual: "the of of of pickled peck where's pickled peter of where's",
# Steps Taken: 482,
# Decode Time: 1.0453775969799608,
# Backtrace Time: 0.00030618696473538876
#
# File: 0175.wav,
# Errors: (7, 0, 2),
# WER: 90.0,
# Expected: "peter piper picked pickled peppers a peck of pickled peppers",
# actual: "the of of of pickled picked peppers of piper where's pickled where's",
# Steps Taken: 510,
# Decode Time: 1.0924191570375115,
# Backtrace Time: 0.0003271070308983326
#
# File: 0176.wav,
# Errors: (4, 0, 1),
# WER: 100.0,
# Expected: "a peck of pickled peppers",
# actual: "pickled of the of of where's",
# Steps Taken: 315,
# Decode Time: 0.6710858440492302,
# Backtrace Time: 0.000186143908649683
#
# File: 0177.wav,
# Errors: (2, 0, 2),
# WER: 200.0,
# Expected: "picked peppers",
# actual: "the the of of",
# Steps Taken: 187,
# Decode Time: 0.40291013300884515,
# Backtrace Time: 0.00012013805098831654
#
# File: 0178.wav,
# Errors: (3, 0, 4),
# WER: 233.33333333333334,
# Expected: "peter picked peppers",
# actual: "of the of a the of of",
# Steps Taken: 204,
# Decode Time: 0.42609351000282913,
# Backtrace Time: 0.00013541302178055048
#
# File: 0179.wav,
# Errors: (5, 0, 4),
# WER: 180.0,
# Expected: "peter piper picked pickled peppers",
# actual: "the of of of a of a of where's",
# Steps Taken: 315,
# Decode Time: 0.6684163849567994,
# Backtrace Time: 0.00019152299501001835
#
# File: 0180.wav,
# Errors: (6, 0, 2),
# WER: 88.88888888888889,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of peter picked of where's the of of of picked",
# Steps Taken: 417,
# Decode Time: 0.8892288460629061,
# Backtrace Time: 0.00026460294611752033
#
# File: 0181.wav,
# Errors: (5, 1, 1),
# WER: 41.17647058823529,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peck piper peck peck of peck of peppers where's the peck of peck peppers peter piper peck",
# Steps Taken: 648,
# Decode Time: 1.3998917980352417,
# Backtrace Time: 0.00040895596612244844
#
# File: 0182.wav,
# Errors: (6, 1, 0),
# WER: 41.17647058823529,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled of picked peck peck of peppers where's the peck of peck peppers peter peck peck",
# Steps Taken: 699,
# Decode Time: 1.511738455039449,
# Backtrace Time: 0.00043365301098674536
#
# File: 0183.wav,
# Errors: (8, 0, 1),
# WER: 52.94117647058824,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of picked peck of peck peppers where's the peck of peck piper peter of picked",
# Steps Taken: 605,
# Decode Time: 1.3119634130271152,
# Backtrace Time: 0.0003950160462409258
#
# File: 0184.wav,
# Errors: (4, 2, 2),
# WER: 47.05882352941176,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled picked peck of peck of peppers where's the peck of peck of peppers peter peter picked",
# Steps Taken: 579,
# Decode Time: 1.2628382720286027,
# Backtrace Time: 0.0003811049973592162
#
# File: 0185.wav,
# Errors: (5, 1, 2),
# WER: 47.05882352941176,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peck of picked peck of peck of peppers where's the peck of peck of peppers peter peck picked",
# Steps Taken: 571,
# Decode Time: 1.221933469059877,
# Backtrace Time: 0.0003778390819206834
#
# File: 0186.wav,
# Errors: (2, 1, 3),
# WER: 75.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the the of piper picked the a of pickled where's",
# Steps Taken: 520,
# Decode Time: 1.1238078949972987,
# Backtrace Time: 0.00030257797334343195
#
# File: 0187.wav,
# Errors: (2, 1, 1),
# WER: 66.66666666666666,
# Expected: "where's the peck of pickled peppers",
# actual: "where's a of the of peppers",
# Steps Taken: 426,
# Decode Time: 0.9233913630014285,
# Backtrace Time: 0.00023104494903236628
#
# File: 0188.wav,
# Errors: (3, 1, 1),
# WER: 83.33333333333334,
# Expected: "a peck of peppers piper picked",
# actual: "of peck where's piper of the",
# Steps Taken: 417,
# Decode Time: 0.9045280439313501,
# Backtrace Time: 0.0002318450715392828
#
# File: 0189.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "where's the peck peter piper picked",
# actual: "where's the a the the piper a",
# Steps Taken: 392,
# Decode Time: 0.8499551169807091,
# Backtrace Time: 0.00019757600966840982
#
# File: 0190.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked pickled peppers",
# actual: "peter picked pickled peppers",
# Steps Taken: 332,
# Decode Time: 0.7200842410093173,
# Backtrace Time: 0.0001950250007212162
#
# File: 0191.wav,
# Errors: (2, 2, 0),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter the peck of picked peppers",
# Steps Taken: 281,
# Decode Time: 0.5928228510310873,
# Backtrace Time: 0.00017339596524834633
#
# File: 0192.wav,
# Errors: (2, 4, 1),
# WER: 77.77777777777779,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of of of picked the",
# Steps Taken: 349,
# Decode Time: 0.7441129689104855,
# Backtrace Time: 0.0001385509967803955
# File: 0193.wav,
# Errors: (5, 0, 2),
# WER: 140.0,
# Expected: "piper peter picked pickled peppers",
# actual: "peck the the a the piper where's",
# Steps Taken: 298,
# Decode Time: 0.6304382300004363,
# Backtrace Time: 0.00018434401135891676
#
# File: 0194.wav,
# Errors: (4, 0, 4),
# WER: 133.33333333333331,
# Expected: "where's peter piper pickled peppers picked",
# actual: "the where's of of of the where's of picked the",
# Steps Taken: 340,
# Decode Time: 0.7244833080330864,
# Backtrace Time: 0.0001753109972923994
#
# File: 0195.wav,
# Errors: (5, 0, 2),
# WER: 87.5,
# Expected: "picked peppers peter piper picked where's the peck",
# actual: "picked the where's the of of a the the peck",
# Steps Taken: 417,
# Decode Time: 0.8916288060136139,
# Backtrace Time: 0.0002577150007709861
#
# File: 0196.wav,
# Errors: (2, 2, 1),
# WER: 62.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the of piper picked pickled pickled peppers",
# Steps Taken: 409,
# Decode Time: 0.8707254200708121,
# Backtrace Time: 0.00026661402080208063
#
# File: 0197.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter picked pickled peppers",
# actual: "a of picked pickled peppers",
# Steps Taken: 255,
# Decode Time: 0.5371425930643454,
# Backtrace Time: 0.00015733903273940086
#
# File: 0198.wav,
# Errors: (1, 2, 1),
# WER: 50.0,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "of pickled pickled peppers picked piper picked",
# Steps Taken: 468,
# Decode Time: 0.9994412140222266,
# Backtrace Time: 0.000287379021756351
#
# File: 0199.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "pickled peppers picked piper peter",
# actual: "peck peppers picked piper peter",
# Steps Taken: 332,
# Decode Time: 0.7080223750090227,
# Backtrace Time: 0.00018545298371464014
#
# File: 0200.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper peter picked peppers",
# actual: "piper peter picked peppers",
# Steps Taken: 323,
# Decode Time: 0.699867382994853,
# Backtrace Time: 0.0001684729941189289
#
# File: 0201.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peter picked a peck of peppers",
# actual: "peter picked of peck of peppers",
# Steps Taken: 485,
# Decode Time: 1.0518006860511377,
# Backtrace Time: 0.0002722339704632759
#
# File: 0202.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter the peppers pickled",
# actual: "where's peter the peppers pickled",
# Steps Taken: 434,
# Decode Time: 0.9291365349199623,
# Backtrace Time: 0.000259020016528666
#
# File: 0203.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "the picked peter piper",
# actual: "the picked peter piper",
# Steps Taken: 264,
# Decode Time: 0.5579885670449585,
# Backtrace Time: 0.00015512004029005766
#
# File: 0204.wav,
# Errors: (0, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peter",
# actual: "where's peter",
# Steps Taken: 178,
# Decode Time: 0.36893031804356724,
# Backtrace Time: 7.001601625233889e-05
#
# File: 0205.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peppers peppers peppers peppers peppers peppers peppers peppers peppers",
# actual: "peppers peppers peppers peppers peppers peppers peppers peppers peppers",
# Steps Taken: 528,
# Decode Time: 1.137250246014446,
# Backtrace Time: 0.00032493798062205315
#
# File: 0206.wav,
# Errors: (1, 0, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked of peck of pickled peppers",
# Steps Taken: 579,
# Decode Time: 1.2381137679331005,
# Backtrace Time: 0.00032212294172495604
#
# File: 0207.wav,
# Errors: (1, 0, 0),
# WER: 11.11111111111111,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's pickled peck of pickled peppers peter piper picked",
# Steps Taken: 750,
# Decode Time: 1.6169168360065669,
# Backtrace Time: 0.00039705599192529917
#
# File: 0208.wav,
# Errors: (3, 0, 4),
# WER: 140.0,
# Expected: "peter piper picked pickled peppers",
# actual: "the peck a a picked peck pickled of where's",
# Steps Taken: 588,
# Decode Time: 1.2720719850622118,
# Backtrace Time: 0.0003203209489583969
#
# File: 0209.wav,
# Errors: (3, 0, 3),
# WER: 100.0,
# Expected: "peck pickled peppers peter piper picked",
# actual: "picked peck pickled peck where's picked picked of peck",
# Steps Taken: 571,
# Decode Time: 1.221744610927999,
# Backtrace Time: 0.0003259319346398115
#
# File: 0210.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "peter piper picked peck pickled peppers",
# actual: "picked piper picked peck pickled peck where's",
# Steps Taken: 579,
# Decode Time: 1.2526375449961051,
# Backtrace Time: 0.00033370102755725384
#
# File: 0211.wav,
# Errors: (2, 1, 4),
# WER: 116.66666666666667,
# Expected: "peck pickled peppers peter piper picked",
# actual: "peck a pickled of where's picked peck a a",
# Steps Taken: 520,
# Decode Time: 1.1150152060436085,
# Backtrace Time: 0.00029528001323342323
#
# File: 0212.wav,
# Errors: (4, 0, 5),
# WER: 150.0,
# Expected: "peter piper picked peck pickled peppers",
# actual: "the of peck a peck picked the picked pickled peck where's",
# Steps Taken: 588,
# Decode Time: 1.2720189769752324,
# Backtrace Time: 0.0003294820198789239
#
# File: 0213.wav,
# Errors: (0, 1, 0),
# WER: 16.666666666666664,
# Expected: "peter picked a peck of peppers",
# actual: "peter picked peck of peppers",
# Steps Taken: 289,
# Decode Time: 0.6243443220155314,
# Backtrace Time: 0.00019066897220909595
#
# File: 0214.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter pickled peter pickled peppers peppers peppers",
# actual: "peter pickled peter pickled peppers peppers peppers",
# Steps Taken: 374,
# Decode Time: 0.8119003049796447,
# Backtrace Time: 0.00025835505221039057
#
# File: 0215.wav,
# Errors: (0, 0, 1),
# WER: 20.0,
# Expected: "peter peter where's the piper",
# actual: "peter of peter where's the piper",
# Steps Taken: 221,
# Decode Time: 0.4605992709985003,
# Backtrace Time: 0.0001691259676590562
#
# File: 0216.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "pickled picked pickled picked",
# actual: "pickled picked pickled picked",
# Steps Taken: 289,
# Decode Time: 0.6235717129893601,
# Backtrace Time: 0.00020136602688580751
#
# File: 0217.wav,
# Errors: (0, 1, 1),
# WER: 28.57142857142857,
# Expected: "a of the of the of the",
# actual: "of the picked of the of the",
# Steps Taken: 374,
# Decode Time: 0.8112591549288481,
# Backtrace Time: 0.00021086796186864376
#
# File: 0218.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter picked pickled peppers",
# actual: "peter pickled picked of peppers",
# Steps Taken: 357,
# Decode Time: 0.7725487089483067,
# Backtrace Time: 0.0002134630922228098
#
# File: 0219.wav,
# Errors: (2, 0, 0),
# WER: 50.0,
# Expected: "piper picked a peck",
# actual: "piper picked of of",
# Steps Taken: 374,
# Decode Time: 0.8072296439204365,
# Backtrace Time: 0.00021181302145123482
#
# File: 0220.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 255,
# Decode Time: 0.5365751140052453,
# Backtrace Time: 0.00015999097377061844
#
# File: 0221.wav,
# Errors: (2, 0, 0),
# WER: 66.66666666666666,
# Expected: "pickled peppers picked",
# actual: "the peppers of",
# Steps Taken: 264,
# Decode Time: 0.5592932880390435,
# Backtrace Time: 0.00015708093997091055
#
# File: 0222.wav,
# Errors: (2, 0, 1),
# WER: 75.0,
# Expected: "a peck of peppers",
# actual: "of peck of of where's",
# Steps Taken: 246,
# Decode Time: 0.5308551859343424,
# Backtrace Time: 0.00015053001698106527
#
# File: 0223.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "pickled peppers pickled peter peck picked",
# actual: "pickled peppers pickled peter peck peck",
# Steps Taken: 537,
# Decode Time: 1.1582539899973199,
# Backtrace Time: 0.0002762880176305771
#
# File: 0224.wav,
# Errors: (0, 1, 0),
# WER: 20.0,
# Expected: "piper peck of peppers peter",
# actual: "piper peck peppers peter",
# Steps Taken: 400,
# Decode Time: 0.8511927789077163,
# Backtrace Time: 0.00020948599558323622
#
# File: 0225.wav,
# Errors: (1, 1, 1),
# WER: 50.0,
# Expected: "peppers peppers picked of peter pickled",
# actual: "peppers peck where's picked peter pickled",
# Steps Taken: 332,
# Decode Time: 0.7030049250461161,
# Backtrace Time: 0.00019618705846369267
#
# File: 0226.wav,
# Errors: (0, 0, 1),
# WER: 20.0,
# Expected: "peter peter peck of piper",
# actual: "peter peter peck of piper a",
# Steps Taken: 281,
# Decode Time: 0.6066161979688331,
# Backtrace Time: 0.000170120969414711
# File: 0227.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "peppers picked picked of piper pickled",
# actual: "where's picked picked of peck of pickled",
# Steps Taken: 443,
# Decode Time: 0.95645668101497,
# Backtrace Time: 0.00026992103084921837
#
# File: 0228.wav,
# Errors: (3, 1, 1),
# WER: 62.5,
# Expected: "peck peppers pickled the picked pickled the peter",
# actual: "peck of where's pickled of peck pickled peter",
# Steps Taken: 468,
# Decode Time: 0.9998382789781317,
# Backtrace Time: 0.0002872740151360631
#
# File: 0229.wav,
# Errors: (3, 1, 0),
# WER: 33.33333333333333,
# Expected: "piper pickled a piper of peppers picked peter peter pickled peppers peter",
# actual: "pickled of piper of where's picked peter peter pickled where's peter",
# Steps Taken: 648,
# Decode Time: 1.4072941959602758,
# Backtrace Time: 0.0003835780080407858
#
# File: 0230.wav,
# Errors: (2, 0, 0),
# WER: 40.0,
# Expected: "pickled a peck piper of",
# actual: "pickled of where's piper of",
# Steps Taken: 468,
# Decode Time: 0.9977629949571565,
# Backtrace Time: 0.0002600139705464244
#
# File: 0231.wav,
# Errors: (0, 3, 0),
# WER: 17.647058823529413,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter piper picked peck pickled peppers where's the peck pickled peppers peter piper picked",
# Steps Taken: 793,
# Decode Time: 1.7098293569870293,
# Backtrace Time: 0.00047165690921247005
#
# File: 0232.wav,
# Errors: (0, 1, 0),
# WER: 5.88235294117647,
# Expected: "piper peter picked a peck of pickled peppers where's the peck of pickled peppers piper peter picked",
# actual: "piper peter picked peck of pickled peppers where's the peck of pickled peppers piper peter picked",
# Steps Taken: 810,
# Decode Time: 1.7473326749168336,
# Backtrace Time: 0.0004942989908158779
#
# File: 0233.wav,
# Errors: (1, 1, 0),
# WER: 13.333333333333334,
# Expected: "peter picked a peck of pickled peppers where's the peck of pickled peppers peter picked",
# actual: "peter picked of peck pickled peppers where's the peck of pickled peppers peter picked",
# Steps Taken: 767,
# Decode Time: 1.6521043840330094,
# Backtrace Time: 0.00044871808495372534
#
# File: 0234.wav,
# Errors: (1, 0, 0),
# WER: 12.5,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "of peck of pickled peppers peter piper picked",
# Steps Taken: 443,
# Decode Time: 0.9607953460654244,
# Backtrace Time: 0.00026818597689270973
#
# File: 0235.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter peppers picked pickled piper where's the peck of pickled piper",
# actual: "peter peppers picked pickled piper where's the peck of pickled piper",
# Steps Taken: 605,
# Decode Time: 1.310776846949011,
# Backtrace Time: 0.0003690990852192044
#
# File: 0236.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "where's the peck peter piper picked",
# actual: "where's of peck peter of piper picked",
# Steps Taken: 408,
# Decode Time: 0.870163856074214,
# Backtrace Time: 0.0002505499869585037
#
# File: 0237.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "a peck of picked pickled peppers",
# actual: "of picked of picked pickled of where's",
# Steps Taken: 361,
# Decode Time: 0.7714882889995351,
# Backtrace Time: 0.00023528700694441795
#
# File: 0238.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "where's peter piper",
# actual: "where's a of piper",
# Steps Taken: 306,
# Decode Time: 0.6488766600377858,
# Backtrace Time: 0.0001638149842619896
#
# File: 0239.wav,
# Errors: (6, 0, 0),
# WER: 75.0,
# Expected: "a peck of pickled peppers picked peter piper",
# actual: "of picked of a where's a peppers piper",
# Steps Taken: 491,
# Decode Time: 1.0545248120324686,
# Backtrace Time: 0.0002778699854388833
#
# File: 0240.wav,
# Errors: (1, 1, 0),
# WER: 33.33333333333333,
# Expected: "a peck of piper pickled peter",
# actual: "of of piper pickled peter",
# Steps Taken: 389,
# Decode Time: 0.8281290420563892,
# Backtrace Time: 0.00022662896662950516
#
#
# Done

# %%
f = create_wfst()
from subprocess import check_call
from IPython.display import Image
f.draw('tmp.dot', portrait=True)
check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
Image(filename='tmp.png')

# %%
#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
