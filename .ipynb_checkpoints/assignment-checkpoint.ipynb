# %% [markdown]
# # ASR Assignment 2024-25
#
# This notebook has been provided as a template to get you started on the assignment.  Feel free to use it for your development, or do your development directly in Python.
#
# You can find a full description of the assignment [here](https://www.inf.ed.ac.uk/teaching/courses/asr/coursework-2025.html).
#
# You are provided with two Python modules `observation_model.py` and `wer.py`.  The first was described in [Lab 3](https://github.com/yiwang454/asr_labs/blob/main/asr_lab3_4.ipynb).  The second can be used to compute the number of substitution, deletion and insertion errors between ASR output and a reference text.
#
# It can be used as follows:
#
# ```python
# import wer
#
# my_refence = 'A B C'
# my_output = 'A C C D'
#
# wer.compute_alignment_errors(my_reference, my_output)
# ```
#
# This produces a tuple $(s,d,i)$ giving counts of substitution,
# deletion and insertion errors respectively - in this example (1, 0, 1).  The function accepts either two strings, as in the example above, or two lists.  Matching is case sensitive.
#
# ## Template code
#
# Assuming that you have already made a function to generate an WFST, `create_wfst()` and a decoder class, `MyViterbiDecoder`, you can perform recognition on all the audio files as follows:

# %%
import glob
import os
import wer
import observation_model
import openfst_python as fst
import math
import time
from collections import Counter
import heapq

# ... (add your code to create WFSTs and Viterbi Decoder)

# %%
class MyViterbiDecoder:
    
    NLL_ZERO = 1e10  # define a constant representing -log(0).  This is really infinite, but approximate
                     # it here with a very large number
    BEAM_WIDTH = 80
    
    MIN_SURVIVAL = 1
    
    IS_BIGRAM = False
    
    IS_PRUNING = True
    
    temp_phones = []
    
#     BEST_PROB = 0
    
    def __init__(self, f, audio_file_name):
        """Set up the decoder class with an audio file and WFST f
        """
        self.om = observation_model.ObservationModel()
        self.f = f
        
        if audio_file_name:
            self.om.load_audio(audio_file_name)
        else:
            self.om.load_dummy_audio()
        
        self.initialise_decoding()

        
    def initialise_decoding(self):
        """set up the values for V_j(0) (as negative log-likelihoods)
        
        """
        
        self.V = []   # stores likelihood along best path reaching state j
        self.B = []   # stores identity of best previous state reaching state j
        self.W = []   # stores output labels sequence along arc reaching j - this removes need for 
                      # extra code to read the output sequence along the best path
        
        for t in range(self.om.observation_length()+1):
            self.V.append([self.NLL_ZERO]*self.f.num_states())
            self.B.append([-1]*self.f.num_states())
            self.W.append([[] for i in range(self.f.num_states())])  #  multiplying the empty list doesn't make multiple
        
        # The above code means that self.V[t][j] for t = 0, ... T gives the Viterbi cost
        # of state j, time t (in negative log-likelihood form)
        # Initialising the costs to NLL_ZERO effectively means zero probability    
        
        # give the WFST start state a probability of 1.0   (NLL = 0.0)
        self.V[0][self.f.start()] = 0.0
        
        # some WFSTs might have arcs with epsilon on the input (you might have already created 
        # examples of these in earlier labs) these correspond to non-emitting states, 
        # which means that we need to process them without stepping forward in time.  
        # Don't worry too much about this!  
        self.traverse_epsilon_arcs(0)        
        
    def traverse_epsilon_arcs(self, t):
        """Traverse arcs with <eps> on the input at time t
        
        These correspond to transitions that don't emit an observation
        
        We've implemented this function for you as it's slightly trickier than
        the normal case.  You might like to look at it to see what's going on, but
        don't worry if you can't fully follow it.
        
        """
        
        states_to_traverse = list(self.f.states()) # traverse all states
        while states_to_traverse:
            
            # Set i to the ID of the current state, the first 
            # item in the list (and remove it from the list)
            i = states_to_traverse.pop(0)   
        
            # don't bother traversing states which have zero probability
            if self.V[t][i] == self.NLL_ZERO:
                    continue
        
            for arc in self.f.arcs(i):
                
                if arc.ilabel == 0:     # if <eps> transition
                  
                    j = arc.nextstate   # ID of next state  
                
                    if self.V[t][j] > self.V[t][i] + float(arc.weight):
                        
                        # this means we've found a lower-cost path to
                        # state j at time t.  We might need to add it
                        # back to the processing queue.
                        self.V[t][j] = self.V[t][i] + float(arc.weight)
                        
                        # save backtrace information.  In the case of an epsilon transition, 
                        # we save the identity of the best state at t-1.  This means we may not
                        # be able to fully recover the best path, but to do otherwise would
                        # require a more complicated way of storing backtrace information
                        self.B[t][j] = self.B[t][i] 
                        
                        # and save the output labels encountered - this is a list, because
                        # there could be multiple output labels (in the case of <eps> arcs)
                        if arc.olabel != 0:
                            self.W[t][j] = self.W[t][i] + [arc.olabel]
                        else:
                            self.W[t][j] = self.W[t][i]
                        
                        if j not in states_to_traverse:
                            states_to_traverse.append(j)

    
    def forward_step(self, t):
          
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                #if self.V[t-1][i] >= self.PRUNE_THRESHOLD * self.BEST_PROB:

                for arc in self.f.arcs(i):

                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            #self.BEST_PROB = prob #does this need to be state specific?
                            self.V[t][j] = prob
                            self.B[t][j] = i

                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
                                
    def bigram_fs(self, t, bigram):
        
        for i in self.f.states():
            
            if not self.V[t-1][i] == self.NLL_ZERO:   # no point in propagating states with zero probability
                
                #if self.V[t-1][i] >= self.PRUNE_THRESHOLD * self.BEST_PROB:

                for arc in self.f.arcs(i):

                    if arc.ilabel != 0: # <eps> transitions don't emit an observation
                        j = arc.nextstate
                        tp = float(arc.weight)  # transition prob
                        ep = -self.om.log_observation_probability(self.f.input_symbols().find(arc.ilabel), t)  # emission negative log prob
                        prob = tp + ep + self.V[t-1][i] # they're logs
                        if prob < self.V[t][j]:
                            #self.BEST_PROB = prob #does this need to be state specific?
                            self.V[t][j] = prob
                            self.B[t][j] = i

                            # store the output labels encountered too
                            if arc.olabel !=0:
                                self.W[t][j] = [arc.olabel]
                            else:
                                self.W[t][j] = []
                                
    def finalise_decoding(self):
            """ this incorporates the probability of terminating at each state
            """

            best_final_cost = self.NLL_ZERO
            best_final_state = -1

            for state in self.f.states():
                final_weight = float(self.f.final(state))

                if self.V[-1][state] != self.NLL_ZERO:
                    if final_weight != math.inf:
                        self.V[-1][state] += final_weight

                    # Track the best final state
                    if self.V[-1][state] < best_final_cost:
                        best_final_cost = self.V[-1][state]
                        best_final_state = state

            # Fallback: if no final state was reached, use the best available path
            if best_final_state == -1:
                # Pick the lowest-cost path even if it doesn't end at a final state
                best_final_state = min(
                    range(len(self.V[-1])), key=lambda x: self.V[-1][x]
                )

            # Handle case where no path made it to the end
            if self.V[-1][best_final_state] >= self.NLL_ZERO:
                print("No path reached a valid final state. Using best available path.")
        
        
    def decode(self, bigrams):
        start = time.perf_counter()
        self.initialise_decoding()
        t = 1
        while t <= self.om.observation_length():
            if self.IS_BIGRAM:
                self.bigram_fs(t, bigrams)
            else:
                self.forward_step(t)
            self.traverse_epsilon_arcs(t)
            if self.IS_PRUNING:
                self.pruning(t) #comment out if you want to stop pruning
            t += 1
        self.finalise_decoding()
        
        end = time.perf_counter()
        elapsed = end - start
        
        return t, elapsed
    
    #prune function which takes in T and checks the current self.V[t]
    def pruning(self, t):
        current_V = self.V[t] #get the list of states at this timestate
        min_V = min(current_V)
        if min_V == self.NLL_ZERO: #dont prune yet if the minimum V is infinite bc it means the V hasnt been populated
            return
        beam_thresh = min_V + self.BEAM_WIDTH
        for j in self.f.states():
            if current_V[j] > beam_thresh:
                self.V[t][j] = self.NLL_ZERO #set the current time and state vitrbi to be huge so the path is unlikely
    
    def backtrace(self):
        start = time.perf_counter()
        
        best_final_state = self.V[-1].index(min(self.V[-1])) # argmin
        best_state_sequence = [best_final_state]
        best_out_sequence = []
        
        t = self.om.observation_length()   # ie T
        j = best_final_state
        
        while t >= 0:
            i = self.B[t][j]
            best_state_sequence.append(i)
            best_out_sequence = self.W[t][j] + best_out_sequence  # computer scientists might like
                                                                                # to make this more efficient!

            # continue the backtrace at state i, time t-1
            j = i  
            t-=1
            
        best_state_sequence.reverse()
        
        # convert the best output sequence from FST integer labels into strings
        best_out_sequence = ' '.join([self.f.output_symbols().find(label) for label in best_out_sequence])
        #convert out_sequence to words from the phonesdef convert_phones_to_words(phone_sequence, phone_to_word):
        temp_phones = []
        word_sequence = []
        
        for phone in best_out_sequence.split(" "):
            temp_phones.append(phone)
            
            for word, phones in lex.items():
                if phones == temp_phones:
                    if word != "<sil>":
                        word_sequence.append(word)
                    temp_phones.clear()
        word_sequence = " ".join(word_sequence)
        
        end = time.perf_counter()
        elapsed = end - start
        
        return (best_state_sequence, word_sequence, elapsed)

# %%
def parse_lexicon(lex_file):
    """
    Parse the lexicon file and return it in dictionary form.
    
    Args:
        lex_file (str): filename of lexicon file with structure '<word> <phone1> <phone2>...'
                        eg. peppers p eh p er z

    Returns:
        lex (dict): dictionary mapping words to list of phones
    """
    
    lex = {}  # create a dictionary for the lexicon entries (this could be a problem with larger lexica)
    with open(lex_file, 'r') as f:
        for line in f:
            line = line.split()  # split at each space
            lex[line[0]] = line[1:]  # first field the word, the rest is the phones
    lex["<sil>"] = ["sil"]
    return lex

def generate_symbol_tables(lexicon, n=3):
    '''
    Return word, phone and state symbol tables based on the supplied lexicon
        
    Args:
        lexicon (dict): lexicon to use, created from the parse_lexicon() function
        n (int): number of states for each phone HMM
        
    Returns:
        word_table (fst.SymbolTable): table of words
        phone_table (fst.SymbolTable): table of phones
        state_table (fst.SymbolTable): table of HMM phone-state IDs
    '''
    
    state_table = fst.SymbolTable()
    phone_table = fst.SymbolTable()
    word_table = fst.SymbolTable()
    
    # add empty <eps> symbol to all tables
    state_table.add_symbol('<eps>')
    phone_table.add_symbol('<eps>')
    word_table.add_symbol('<eps>')
    
    for word, phones  in lexicon.items():
        
        word_table.add_symbol(word)
        
        for p in phones: # for each phone
            
            phone_table.add_symbol(p)
            for i in range(1,n+1): # for each state 1 to n
                state_table.add_symbol('{}_{}'.format(p, i))
            
    return word_table, phone_table, state_table


# call these two functions
lex = parse_lexicon('lexicon.txt')
word_table, phone_table, state_table = generate_symbol_tables(lex)
# state_table.write_text('tmp.txt')
# print(open('tmp.txt').read())

def generate_phone_wfst(f, start_state, phone, n):
    """
    Generate a WFST representating an n-state left-to-right phone HMM
    
    Args:
        f (fst.Fst()): an FST object, assumed to exist already
        start_state (int): the index of the first state, assmed to exist already
        phone (str): the phone label 
        n (int): number of states for each phone HMMectly modified i
        
    Returns:
        the final state of the FST
    """
    
    current_state = start_state
    
    for i in range(1, n+1):
        
        in_label = state_table.find('{}_{}'.format(phone, i))
        
        sl_weight = fst.Weight('log', -math.log(0.9))  # weight for self-loop
        # self-loop back to current state
        f.add_arc(current_state, fst.Arc(in_label, 0, sl_weight, current_state))
        
        # transition to next state
        
        # we want to output the phone label on the final state
        # note: if outputting words instead this code should be modified
        if i == n:
            out_label = phone_table.find(phone)
        else:
            out_label = 0   # output empty <eps> label
            
        next_state = f.add_state()
        next_weight = fst.Weight('log', -math.log(0.1)) # weight to next state
        f.add_arc(current_state, fst.Arc(in_label, out_label, next_weight, next_state))    
       
        current_state = next_state
        
    return current_state

# %%
# Load words from lexicon
word_list = []
with open("lexicon.txt", "r") as lexicon:
    for line in lexicon:
        word = line.split()[0].lower()  # Extract only the first word
        word_list.append(word)

# Count word occurrences
word_counts = Counter(word_list)

# Total number of words
total_words = sum(word_counts.values())

# Compute unigram probabilities
word_probs = {word: count / total_words for word, count in word_counts.items()}

# Print top words
# for word, prob in sorted(word_probs.items(), key=lambda x: x[1], reverse=True):
#     print(f"{word}: {prob:.5f}")

# %%
def read_transcription(wav_file):
    """
    Get the transcription corresponding to wav_file.
    """
    
    transcription_file = os.path.splitext(wav_file)[0] + '.txt'
    
    with open(transcription_file, 'r') as f:
        transcription = f.readline().strip()
    
    return transcription

all_transcription = []

for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'): 
    ts = read_transcription(wav_file)
    all_transcription.append(ts)
    
#print(all_transcription)    


def build_bigram_model_backoff(corpus):
    bigram_model = {}
    unigram_counts = Counter()
    
    for sentence in corpus:
        words = sentence.split()
        for word in words:
            unigram_counts[word] += 1
        for i in range(len(words) - 1):
            if words[i] not in bigram_model:
                bigram_model[words[i]] = Counter()
            bigram_model[words[i]][words[i+1]] += 1
    
    total_unigrams = sum(unigram_counts.values())
    unigram_probs = {word: count / total_unigrams for word, count in unigram_counts.items()}
    
    # Convert counts to negative log probabilities with backoff
    for word, following in bigram_model.items():
        total_count = sum(following.values())
        for next_word, count in following.items():
            if next_word == "of":
                bigram_model[word] = {next_word: ((count / total_count) * 0.95)}
            else: 
                bigram_model[word] = {next_word: ((count / total_count) * 0.95)}
        
        # Backoff to unigram probability scaled by 0.05
        for next_word in unigram_probs:
            if next_word not in bigram_model[word]:
                bigram_model[word][next_word] = (unigram_probs[next_word] * 0.05)
        bigram_model[word].update({"<sil>": (1/11)})
    words = bigram_model.keys()
    bigram_model["<sil>"] = {word : (1/11) for word in words}
    bigram_model["<sil>"].update({"<sil>": (1/11)})
    
    return bigram_model


def verify_probabilities(bigram_model):
    for word, transitions in bigram_model.items():
        total_prob = sum(transitions.values())
        if not (0.999 <= total_prob <= 1.001):  # Allowing small floating-point errors
            print(f"Warning: Probabilities for '{word}' sum to {total_prob}, not 1")
        else:
            print(f"'{word}' probabilities sum correctly to {total_prob}")


bigrams = build_bigram_model_backoff(all_transcription)
verify_probabilities(bigrams)
# print(bigrams["a"].keys())
# Out:
#   File "/tmp/ipykernel_120157/1078227763.py", line 37
#     bigram_model[word] = {(next_word: -math.log((count / total_count)*(10/11)) if next_word != "of" else (next_word: -math.log((count / 2*total_count)*(10/11))) for next_word, count in following.items()}
#                                     ^
# SyntaxError: invalid syntax

# %%
# def build_bigram_model(corpus):
#     bigram_model = {}
    
#     #bigrams store P(X | Y) as Y:{X:0.5, Z:0.5}
    
#     for sentence in corpus:
#         words = sentence.split()
#         for i in range(len(words) - 1):
#             if words[i] not in bigram_model:
#                 bigram_model[words[i]] = Counter()
#             bigram_model[words[i]][words[i+1]] += 1
    
#     # Convert counts to probabilities
#     for word, following in bigram_model.items():
#         total_count = sum(following.values())
#         bigram_model[word] = {next_word: -math.log((count / total_count)*(10/11)) for next_word, count in following.items()}
#         bigram_model[word].update({"<sil>": -math.log(1/11)})
    
#     #instead of making a silence dictionary within bigram, we use the last actual word to inform the weight of the next arc
#     #this doesnt work for moving to silence as we need to have a probability
#     return bigram_model

# %%
def create_wfst(bigram):
    """ generate a HMM to recognise any single word sequence for words in the lexicon
    
    Args:
        n (int): states per phone HMM

    Returns:
        the constructed WFST
    
    """
    
    BIGRAM_THRESHOLD = 0.1
    
    f = fst.Fst('log')
    n = 3
    f.set_input_symbols(state_table)
    f.set_output_symbols(phone_table)
    # create a single start state
    start_state = f.add_state()
    f.set_start(start_state)

    f_weight = fst.Weight('log', -math.log(1)) #when no silence, set final weight to -log(1)
    start_weight = fst.Weight('log', -math.log(1/11))
    
    first_states = []
    final_states = []
    for word, phones in lex.items():
        current_state = f.add_state()
        first_states.append((current_state, word))
        
        f.add_arc(start_state, fst.Arc(0, 0, start_weight, current_state))
        for phone in phones: 
            current_state = generate_phone_wfst(f, current_state, phone, n)
        # note: new current_state is now set to the final state of the previous phone WFST
        
        f.set_final(current_state)
        
        f.add_arc(current_state, fst.Arc(0, 0, f_weight, start_state))
        
        final_states.append((current_state, word))
        
    for current_state, current_word in final_states:
        #print(current_word)
        for next_state, next_word in first_states:
            #if bigram[current_word][next_word] > BIGRAM_THRESHOLD:
                #print(next_word)
                #print(bigram[current_word][next_word])    
            f.add_arc(current_state, fst.Arc(0, 0, fst.Weight('log', -math.log(bigram[current_word][next_word])), next_state)) 
        
    return f
# bigrams = build_bigram_model_backoff(all_transcription)
# f = create_wfst(bigrams)
# from subprocess import check_call
# from IPython.display import Image
# f.draw('tmp.dot', portrait=True)
# check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
# Image(filename='tmp.png')

# %%
#with open("Task 2 silence test.txt", "w") as file:

with open("Task 4 Bigram with Backoff 0.05 unseen non determinised.txt", "w") as file:
    bigram = build_bigram_model_backoff(all_transcription)
    f = create_wfst(bigram)
#     if bigram:
#         comp2 = fst.compose(f, G2)
#         f = fst.determinize(comp2)
#     print(f)
#     f = fst.determinize(f)
    state_count = 0
    arc_count = 0
    for state in f.states():
        state_count += 1
        arc_count += len([arc for arc in f.arcs(state)])

        
    
        
    print(f'State Count: {state_count}, \nArc Count: {arc_count} \n')
    file.write(f"State Count: {state_count}, Arc Count: {arc_count} \n")


    for wav_file in glob.glob('/group/teaching/asr/labs/recordings/*.wav'):    # replace path if using your own
                                                                               # audio files

        decoder = MyViterbiDecoder(f, wav_file)

        decode_steps, decode_time = decoder.decode(bigram)
        (state_path, words, backtrace_time) = decoder.backtrace()  # you'll need to modify the backtrace() from Lab 4
                                                   # to return the words along the best path

        transcription = read_transcription(wav_file)
        error_counts = wer.compute_alignment_errors(transcription, words)
        word_count = len(transcription.split())

        word_error_rate = error_counts[0] + error_counts[1] + error_counts[2]

        word_error_rate = (word_error_rate/word_count)*100
        wav_file_name = wav_file.split("/")[-1]

        print(f'File: {wav_file_name}, \nErrors: {error_counts}, \nWER: {word_error_rate}, \nExpected: "{transcription}",\nactual: "{words}", \nSteps Taken: {decode_steps}, \nDecode Time: {decode_time}, \nBacktrace Time: {backtrace_time} \n')
        file.write(f'File: {wav_file_name}, \nErrors: {error_counts}, \nWER: {word_error_rate}, \nExpected: "{transcription}",\nActual: "{words}", \nSteps Taken: {decode_steps}, \nDecode Time: {decode_time}, \nBacktrace Time: {backtrace_time} \n')

print("\nDone")
        # you'll need to accumulate these to produce an overall Word Error Rate
# Out:
# State Count: 120,
# Arc Count: 359
#
# File: 0000.wav,
# Errors: (3, 1, 2),
# WER: 75.0,
# Expected: "peter piper pickled a peck of picked peppers",
# actual: "where's of a of pickled of peck of picked",
# Steps Taken: 758,
# Decode Time: 1.6528407860023435,
# Backtrace Time: 0.0003800360136665404
#
# File: 0001.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "peter the piper of pickled peppers",
# actual: "peter the piper of a where's where's",
# Steps Taken: 878,
# Decode Time: 1.8403652400011197,
# Backtrace Time: 0.0004038719926029444
#
# File: 0002.wav,
# Errors: (3, 0, 3),
# WER: 66.66666666666666,
# Expected: "picked piper peter peppers pickled of peck the where's",
# actual: "picked a of peter peck where's pickled where's peck a the where's",
# Steps Taken: 784,
# Decode Time: 1.6757025090046227,
# Backtrace Time: 0.000397794006858021
#
# File: 0003.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peppers pickled peter a peck pickled",
# actual: "peppers pickled peter of peck pickled",
# Steps Taken: 485,
# Decode Time: 1.0287874240020756,
# Backtrace Time: 0.00034065800718963146
#
# File: 0004.wav,
# Errors: (0, 0, 1),
# WER: 16.666666666666664,
# Expected: "piper peter picked a pickled piper",
# actual: "piper of peter picked a pickled piper",
# Steps Taken: 426,
# Decode Time: 0.8378246230131481,
# Backtrace Time: 0.00025170700973831117
#
# File: 0005.wav,
# Errors: (3, 0, 0),
# WER: 42.857142857142854,
# Expected: "picked peppers pickled piper a the where's",
# actual: "picked peppers pickled pickled of peter where's",
# Steps Taken: 605,
# Decode Time: 1.1781555250054225,
# Backtrace Time: 0.00033110802178271115
#
# File: 0006.wav,
# Errors: (2, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's a peter pickled picked peppers",
# actual: "where's of peter pickled a peppers",
# Steps Taken: 426,
# Decode Time: 0.8849732340022456,
# Backtrace Time: 0.000256102008279413
#
# File: 0007.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peck pickled piper where's the peppers",
# actual: "peck pickled piper where's the where's",
# Steps Taken: 426,
# Decode Time: 0.8033521019970067,
# Backtrace Time: 0.0002542169822845608
#
# File: 0008.wav,
# Errors: (2, 4, 0),
# WER: 54.54545454545454,
# Expected: "picked of picked of peck of peter of peck peter pickled",
# actual: "picked a peck of pickled peck peter",
# Steps Taken: 366,
# Decode Time: 0.7910374789789785,
# Backtrace Time: 0.00022887898376211524
#
# File: 0009.wav,
# Errors: (1, 1, 2),
# WER: 44.44444444444444,
# Expected: "pickled of peppers pickled of peck pickled of peter",
# actual: "the a the of peppers pickled of peck pickled of",
# Steps Taken: 383,
# Decode Time: 0.782928896980593,
# Backtrace Time: 0.0002636499993968755
#
# File: 0010.wav,
# Errors: (5, 2, 0),
# WER: 87.5,
# Expected: "peter peck peck peppers of pickled peter peck",
# actual: "the of piper the where's pickled",
# Steps Taken: 298,
# Decode Time: 0.5987585289985873,
# Backtrace Time: 0.00016882200725376606
#
# File: 0011.wav,
# Errors: (7, 1, 1),
# WER: 81.81818181818183,
# Expected: "peter piper picked peter peppers peck peter pickled piper picked picked",
# actual: "pickled where's a a the where's a peter pickled piper a",
# Steps Taken: 520,
# Decode Time: 1.071884797012899,
# Backtrace Time: 0.0003155209997203201
#
# File: 0012.wav,
# Errors: (2, 1, 1),
# WER: 80.0,
# Expected: "peter picked the pickled peppers",
# actual: "picked of picked peck peppers",
# Steps Taken: 332,
# Decode Time: 0.6864536869979929,
# Backtrace Time: 0.0001758849830366671
#
# File: 0013.wav,
# Errors: (0, 1, 1),
# WER: 33.33333333333333,
# Expected: "where's peter picked a peck piper",
# actual: "where's peter picked peck piper of",
# Steps Taken: 451,
# Decode Time: 0.8492798740044236,
# Backtrace Time: 0.0002647259971126914
#
# File: 0014.wav,
# Errors: (2, 0, 0),
# WER: 28.57142857142857,
# Expected: "picked a peck of pickled peppers peter",
# actual: "picked of peck of peck peppers peter",
# Steps Taken: 494,
# Decode Time: 1.0252975070034154,
# Backtrace Time: 0.0002843959955498576
#
# File: 0015.wav,
# Errors: (1, 1, 1),
# WER: 42.857142857142854,
# Expected: "pickled peppers a peck where's peter piper",
# actual: "pickled peppers peck where's the of piper",
# Steps Taken: 511,
# Decode Time: 0.9757907110033557,
# Backtrace Time: 0.0002986320178024471
#
# File: 0016.wav,
# Errors: (3, 1, 1),
# WER: 62.5,
# Expected: "where's the peppers peter piper picked a peck",
# actual: "where's peppers picked of piper of peck peck",
# Steps Taken: 502,
# Decode Time: 0.9698967539879959,
# Backtrace Time: 0.00029027697746641934
#
# File: 0017.wav,
# Errors: (1, 2, 1),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the piper of picked peck pickled peppers",
# Steps Taken: 511,
# Decode Time: 1.1148435859940946,
# Backtrace Time: 0.00028356400434859097
#
# File: 0018.wav,
# Errors: (2, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of picked peppers peter piper picked",
# actual: "where's the peck picked peppers picked piper a",
# Steps Taken: 520,
# Decode Time: 1.0512070679978933,
# Backtrace Time: 0.00030319797224365175
#
# File: 0019.wav,
# Errors: (2, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's the peck the peppers peck piper picked",
# Steps Taken: 426,
# Decode Time: 0.8329442600079346,
# Backtrace Time: 0.0003141000051982701
#
# File: 0020.wav,
# Errors: (0, 1, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked peck of pickled peppers",
# Steps Taken: 485,
# Decode Time: 0.9586757910146844,
# Backtrace Time: 0.00030132001847960055
#
# File: 0021.wav,
# Errors: (2, 1, 1),
# WER: 44.44444444444444,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's the peck picked peppers peter piper of a",
# Steps Taken: 528,
# Decode Time: 1.0552257660019677,
# Backtrace Time: 0.00031146701076067984
#
# File: 0022.wav,
# Errors: (1, 0, 0),
# WER: 25.0,
# Expected: "peter piper picked peppers",
# actual: "peter peter picked peppers",
# Steps Taken: 366,
# Decode Time: 0.7738498050021008,
# Backtrace Time: 0.00021000098786316812
#
# File: 0023.wav,
# Errors: (2, 0, 1),
# WER: 75.0,
# Expected: "peppers peter piper picked",
# actual: "where's peter piper peck a",
# Steps Taken: 298,
# Decode Time: 0.5885583549970761,
# Backtrace Time: 0.00017212700913660228
#
# File: 0024.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter piper pickled peppers",
# actual: "the of piper pickled peppers",
# Steps Taken: 340,
# Decode Time: 0.7019228749850299,
# Backtrace Time: 0.00011886100401170552
#
# File: 0025.wav,
# Errors: (1, 1, 0),
# WER: 28.57142857142857,
# Expected: "where's the pickled peppers peter piper pickled",
# actual: "where's pickled peppers peter piper picked",
# Steps Taken: 460,
# Decode Time: 0.8851437919947784,
# Backtrace Time: 0.0002913100179284811
#
# File: 0026.wav,
# Errors: (3, 0, 3),
# WER: 35.294117647058826,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter piper peck a picked a of pickled peppers where's the peck of picked peppers peter piper picked a picked",
# Steps Taken: 886,
# Decode Time: 1.5964348200068343,
# Backtrace Time: 0.0005551850190386176
#
# File: 0027.wav,
# Errors: (1, 1, 2),
# WER: 133.33333333333331,
# Expected: "peter piper picked",
# actual: "the picked peter a",
# Steps Taken: 349,
# Decode Time: 0.7075657999957912,
# Backtrace Time: 0.0001887609832920134
#
# File: 0028.wav,
# Errors: (2, 4, 0),
# WER: 75.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the peck pickled where's",
# Steps Taken: 451,
# Decode Time: 0.9638698660128284,
# Backtrace Time: 0.00024389199097640812
#
# File: 0029.wav,
# Errors: (3, 2, 2),
# WER: 77.77777777777779,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "the where's peck pickled peppers the of peter the",
# Steps Taken: 579,
# Decode Time: 1.1539857939933427,
# Backtrace Time: 0.000323096988722682
#
# File: 0030.wav,
# Errors: (0, 1, 1),
# WER: 66.66666666666666,
# Expected: "where's peter piper",
# actual: "pickled where's peter",
# Steps Taken: 383,
# Decode Time: 0.7854098920070101,
# Backtrace Time: 0.00021920001017861068
#
# File: 0031.wav,
# Errors: (4, 0, 1),
# WER: 83.33333333333334,
# Expected: "where's the peter peppers peppers a",
# actual: "where's of the of where's where's piper",
# Steps Taken: 477,
# Decode Time: 0.9279665350040887,
# Backtrace Time: 0.00027281499933451414
# File: 0032.wav,
# Errors: (3, 1, 0),
# WER: 66.66666666666666,
# Expected: "peck peter the peppers of piper",
# actual: "a the picked where's piper",
# Steps Taken: 357,
# Decode Time: 0.803002992994152,
# Backtrace Time: 0.00021622399799525738
#
# File: 0033.wav,
# Errors: (4, 1, 1),
# WER: 85.71428571428571,
# Expected: "peter picked peter peppers where's the piper",
# actual: "picked a where's of where's where's picked",
# Steps Taken: 374,
# Decode Time: 0.7942386259965133,
# Backtrace Time: 0.0002392590104136616
#
# File: 0034.wav,
# Errors: (0, 1, 0),
# WER: 20.0,
# Expected: "peter where's the pickled peter",
# actual: "peter where's pickled peter",
# Steps Taken: 400,
# Decode Time: 0.7729428400052711,
# Backtrace Time: 0.00023891800083220005
#
# File: 0035.wav,
# Errors: (5, 1, 0),
# WER: 75.0,
# Expected: "peck the peppers peter where's the peck peck",
# actual: "peck of where's where's of a a",
# Steps Taken: 323,
# Decode Time: 0.6616356769809499,
# Backtrace Time: 0.00016516397590748966
#
# File: 0036.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "where's a peck of peter piper",
# actual: "where's of peck of peter piper of",
# Steps Taken: 315,
# Decode Time: 0.5426149219856597,
# Backtrace Time: 0.0001162990229204297
#
# File: 0037.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper picked peppers peter pickled",
# actual: "piper picked peppers peter pickled",
# Steps Taken: 352,
# Decode Time: 0.6470465260208584,
# Backtrace Time: 0.0001447309914510697
#
# File: 0038.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter piper pickled peppers",
# actual: "peter piper pickled peppers",
# Steps Taken: 306,
# Decode Time: 0.5733181810064707,
# Backtrace Time: 0.0001246939937118441
#
# File: 0039.wav,
# Errors: (2, 0, 0),
# WER: 50.0,
# Expected: "peppers picked a peter",
# actual: "where's picked peck peter",
# Steps Taken: 259,
# Decode Time: 0.5078949790040497,
# Backtrace Time: 9.424801100976765e-05
#
# File: 0040.wav,
# Errors: (1, 0, 1),
# WER: 40.0,
# Expected: "pickled peck of pickled peppers",
# actual: "pickled peck of pickled peck where's",
# Steps Taken: 352,
# Decode Time: 0.6999906839919277,
# Backtrace Time: 0.0001414489815942943
#
# File: 0041.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's pickled peter piper",
# actual: "where's pickled peter piper",
# Steps Taken: 340,
# Decode Time: 0.6557519549969584,
# Backtrace Time: 0.00015224298113025725
#
# File: 0042.wav,
# Errors: (0, 0, 1),
# WER: 50.0,
# Expected: "where's peter",
# actual: "the where's peter",
# Steps Taken: 315,
# Decode Time: 0.5350241640117019,
# Backtrace Time: 0.00010995098273269832
#
# File: 0043.wav,
# Errors: (3, 0, 2),
# WER: 100.0,
# Expected: "pickled peppers picked peter piper",
# actual: "the a picked where's a picked piper",
# Steps Taken: 477,
# Decode Time: 0.9565645179827698,
# Backtrace Time: 0.00029070599703118205
#
# File: 0044.wav,
# Errors: (2, 1, 3),
# WER: 66.66666666666666,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "pickled where's peck a of peck of where's peter piper picked",
# Steps Taken: 528,
# Decode Time: 1.072510419995524,
# Backtrace Time: 0.0003350580227561295
#
# File: 0045.wav,
# Errors: (3, 0, 4),
# WER: 140.0,
# Expected: "a peck of pickled peppers",
# actual: "the the piper peck a where's of of where's",
# Steps Taken: 400,
# Decode Time: 0.7563867080025375,
# Backtrace Time: 0.00024732499150559306
#
# File: 0046.wav,
# Errors: (7, 5, 0),
# WER: 70.58823529411765,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the where's of of a where's of a where's peter piper peck",
# Steps Taken: 844,
# Decode Time: 1.7970155350049026,
# Backtrace Time: 0.0004303530149627477
#
# File: 0047.wav,
# Errors: (6, 5, 2),
# WER: 76.47058823529412,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of a of picked where's peck pickled picked piper of peck",
# Steps Taken: 485,
# Decode Time: 1.0658378360094503,
# Backtrace Time: 0.00031737799872644246
#
# File: 0048.wav,
# Errors: (7, 0, 3),
# WER: 58.82352941176471,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of of of peck of pickled picked where's where's the peck where's pickled peppers peter piper peck",
# Steps Taken: 1151,
# Decode Time: 2.321639836009126,
# Backtrace Time: 0.0006450910004787147
#
# File: 0049.wav,
# Errors: (4, 2, 7),
# WER: 76.47058823529412,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "picked a of peck of a pickled pickled picked where's where's the of a where's of peck where's peppers peter piper peck",
# Steps Taken: 1228,
# Decode Time: 2.3593253059952985,
# Backtrace Time: 0.0007030590204522014
#
# File: 0050.wav,
# Errors: (7, 3, 3),
# WER: 76.47058823529412,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of a of peck of picked where's peck pickled picked picked the picked peck",
# Steps Taken: 588,
# Decode Time: 1.2540566110110376,
# Backtrace Time: 0.0003610550193116069
#
# File: 0051.wav,
# Errors: (4, 0, 0),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "a piper peck of peck of pickled peck",
# Steps Taken: 366,
# Decode Time: 0.7949200980074238,
# Backtrace Time: 0.0002436010108795017
#
# File: 0052.wav,
# Errors: (3, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "peppers the peck of pickled peppers the piper peck",
# Steps Taken: 468,
# Decode Time: 0.9065463540027849,
# Backtrace Time: 0.00029441199149005115
#
# File: 0053.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked piper peppers of the peck",
# actual: "peter picked piper peppers of the peck",
# Steps Taken: 357,
# Decode Time: 0.6740154289873317,
# Backtrace Time: 0.00019978999625891447
#
# File: 0054.wav,
# Errors: (1, 0, 0),
# WER: 14.285714285714285,
# Expected: "where's a pickled the peppers peck of",
# actual: "where's of pickled the peppers peck of",
# Steps Taken: 357,
# Decode Time: 0.6194470800110139,
# Backtrace Time: 0.00013362799654714763
#
# File: 0055.wav,
# Errors: (3, 0, 0),
# WER: 14.285714285714285,
# Expected: "peppers piper peter pickled peck of piper where's a the picked peter of piper peppers picked the a where's the peter",
# actual: "peppers piper peter pickled peck of piper where's of the peck peter of piper peppers picked the of where's the peter",
# Steps Taken: 921,
# Decode Time: 1.6821663200098556,
# Backtrace Time: 0.0005706069932784885
#
# File: 0056.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter piper picked peppers",
# actual: "peter piper picked peppers",
# Steps Taken: 400,
# Decode Time: 0.7388980810064822,
# Backtrace Time: 0.00023589099873788655
#
# File: 0057.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck piper picked",
# actual: "where's the peck piper picked",
# Steps Taken: 400,
# Decode Time: 0.6658233359921724,
# Backtrace Time: 0.00020193101954646409
#
# File: 0058.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "pickled peppers peter picked",
# actual: "pickled peck where's peter picked",
# Steps Taken: 383,
# Decode Time: 0.7594630279927514,
# Backtrace Time: 0.0002018630038946867
#
# File: 0059.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "a peck of pickled peppers",
# actual: "of peck of pickled peppers",
# Steps Taken: 306,
# Decode Time: 0.5560682019859087,
# Backtrace Time: 0.00016909799887798727
#
# File: 0060.wav,
# Errors: (0, 1, 0),
# WER: 25.0,
# Expected: "peter picked a peck",
# actual: "peter picked peck",
# Steps Taken: 340,
# Decode Time: 0.6191895330266561,
# Backtrace Time: 0.0001208609901368618
#
# File: 0061.wav,
# Errors: (8, 2, 1),
# WER: 64.70588235294117,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled of peck of pickled where's where's peck peck of pickled where's the of a peck",
# Steps Taken: 912,
# Decode Time: 1.8993842230120208,
# Backtrace Time: 0.0005609790096059442
#
# File: 0062.wav,
# Errors: (4, 0, 1),
# WER: 55.55555555555556,
# Expected: "peter picked peck peppers where's peck pickled peter picked",
# actual: "peter a peck peppers where's a pickled the of peck",
# Steps Taken: 707,
# Decode Time: 1.4168468179996125,
# Backtrace Time: 0.00037911199615336955
# File: 0063.wav,
# Errors: (5, 0, 3),
# WER: 133.33333333333331,
# Expected: "peter piper peter piper peter piper",
# actual: "the of peter of a peck the of a",
# Steps Taken: 340,
# Decode Time: 0.752544579008827,
# Backtrace Time: 0.00019342699670232832
#
# File: 0064.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "pickled peppers pickled peck pickled peppers",
# actual: "pickled where's pickled peck the pickled where's",
# Steps Taken: 417,
# Decode Time: 0.9050847700273152,
# Backtrace Time: 0.00027263100491836667
#
# File: 0065.wav,
# Errors: (5, 3, 0),
# WER: 100.0,
# Expected: "picked picked picked peck picked picked picked peppers",
# actual: "pickled a pickled pickled where's",
# Steps Taken: 409,
# Decode Time: 0.8669136530079413,
# Backtrace Time: 0.00025308100157417357
#
# File: 0066.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper pickled of peck peter",
# actual: "piper pickled of peck peter",
# Steps Taken: 392,
# Decode Time: 0.7578587830066681,
# Backtrace Time: 0.00023800498456694186
#
# File: 0067.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter peter peppers peter peppers pickled",
# actual: "where's peter peter peppers peter peppers pickled",
# Steps Taken: 588,
# Decode Time: 1.211694441997679,
# Backtrace Time: 0.00032524700509384274
#
# File: 0068.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peck peck pickled pickled peter peppers piper",
# actual: "peck peck pickled pickled peter peppers piper",
# Steps Taken: 451,
# Decode Time: 0.8908627280034125,
# Backtrace Time: 0.0002785820106510073
#
# File: 0069.wav,
# Errors: (1, 2, 0),
# WER: 16.666666666666664,
# Expected: "where's peter the peppers pickled piper of a peck pickled peter piper peck peck of a peter piper",
# actual: "where's peter of peppers pickled piper of peck pickled peter piper peck peck of peter piper",
# Steps Taken: 861,
# Decode Time: 1.589644824998686,
# Backtrace Time: 0.0004856589948758483
#
# File: 0070.wav,
# Errors: (1, 1, 0),
# WER: 25.0,
# Expected: "peppers of a pickled peppers peter where's piper",
# actual: "peppers of pickled peppers peter where's peck",
# Steps Taken: 417,
# Decode Time: 0.8317149429931305,
# Backtrace Time: 0.00026232798700220883
#
# File: 0071.wav,
# Errors: (7, 1, 3),
# WER: 64.70588235294117,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter peck a pickled peck the pickled peck where's where's picked peck pickled pickled peppers the the peter picked",
# Steps Taken: 989,
# Decode Time: 2.100429748010356,
# Backtrace Time: 0.0005908129969611764
#
# File: 0072.wav,
# Errors: (1, 0, 0),
# WER: 5.88235294117647,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter piper picked of peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# Steps Taken: 963,
# Decode Time: 1.7140552719938569,
# Backtrace Time: 0.0005520889826584607
#
# File: 0073.wav,
# Errors: (1, 2, 1),
# WER: 25.0,
# Expected: "peter piper picked a peck of pickled peppers peter piper picked a peck of pickled peppers",
# actual: "peter piper picked of pickled pickled peppers peter piper picked of peck of pickled peppers",
# Steps Taken: 997,
# Decode Time: 1.9599083840148523,
# Backtrace Time: 0.0005717379972338676
#
# File: 0074.wav,
# Errors: (2, 2, 0),
# WER: 22.22222222222222,
# Expected: "where's the peck of pickled peppers peter piper picked where's the peck of pickled peppers peter piper picked",
# actual: "where's the peck of pickled peppers picked picked where's the peck pickled peppers peter peter picked",
# Steps Taken: 1006,
# Decode Time: 1.8579403939947952,
# Backtrace Time: 0.0005836949858348817
#
# File: 0075.wav,
# Errors: (1, 6, 3),
# WER: 40.0,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked peter piper picked a peck of pickled peppers",
# actual: "pickled peter picked of pickled pickled peppers where's the pickled pickled peppers peter piper picked peter piper picked of pickled pickled peppers",
# Steps Taken: 1416,
# Decode Time: 2.725608074979391,
# Backtrace Time: 0.0008725750085432082
#
# File: 0076.wav,
# Errors: (3, 0, 3),
# WER: 120.0,
# Expected: "peter piper picked pickled peppers",
# actual: "the picked piper the a pickled peter peck",
# Steps Taken: 779,
# Decode Time: 1.6005893690162338,
# Backtrace Time: 0.00038505898555740714
#
# File: 0077.wav,
# Errors: (1, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's peter piper",
# actual: "where's pickled piper",
# Steps Taken: 417,
# Decode Time: 0.8335215199913364,
# Backtrace Time: 0.00023693699040450156
#
# File: 0078.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter pickled a peck of peppers",
# actual: "the picked pickled of peck of peter",
# Steps Taken: 473,
# Decode Time: 0.990934247005498,
# Backtrace Time: 0.0002799609792418778
#
# File: 0079.wav,
# Errors: (2, 1, 1),
# WER: 50.0,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "peck of pickled where's peter piper the a",
# Steps Taken: 603,
# Decode Time: 1.1616405739914626,
# Backtrace Time: 0.0004030390118714422
#
# File: 0080.wav,
# Errors: (3, 0, 2),
# WER: 55.55555555555556,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "the where's of peck of pickled peppers pickled piper a the",
# Steps Taken: 593,
# Decode Time: 1.138915643998189,
# Backtrace Time: 0.0003560399927664548
#
# File: 0081.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter picked peppers",
# actual: "peter picked picked picked",
# Steps Taken: 268,
# Decode Time: 0.5400029710144736,
# Backtrace Time: 0.00017796398606151342
#
# File: 0082.wav,
# Errors: (3, 0, 1),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the of piper picked of piper of pickled peppers",
# Steps Taken: 613,
# Decode Time: 1.1763359709875658,
# Backtrace Time: 0.00035675999242812395
#
# File: 0083.wav,
# Errors: (2, 2, 1),
# WER: 55.55555555555556,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of pickled pickled of peter piper peck",
# Steps Taken: 485,
# Decode Time: 0.8900774920184631,
# Backtrace Time: 0.00029449601424857974
#
# File: 0084.wav,
# Errors: (2, 1, 2),
# WER: 62.5,
# Expected: "pickled peppers picked a peck of peter piper",
# actual: "pickled of where's a of pickled peter of piper",
# Steps Taken: 588,
# Decode Time: 1.1414239070145413,
# Backtrace Time: 0.00034556700848042965
#
# File: 0085.wav,
# Errors: (1, 2, 2),
# WER: 55.55555555555556,
# Expected: "where's the peck of peter piper pickled peppers picked",
# actual: "where's of pickled peter piper pickled peck where's picked",
# Steps Taken: 562,
# Decode Time: 0.98610898599145,
# Backtrace Time: 0.0003379860136192292
#
# File: 0086.wav,
# Errors: (2, 1, 2),
# WER: 62.5,
# Expected: "peter peppers picked pickled peck of peter piper",
# actual: "peter piper where's picked the pickled pickled peter piper",
# Steps Taken: 528,
# Decode Time: 0.9347435600066092,
# Backtrace Time: 0.0003348820027895272
#
# File: 0087.wav,
# Errors: (3, 0, 1),
# WER: 80.0,
# Expected: "pickled piper picked pickled peter",
# actual: "picked piper peck the peter peter",
# Steps Taken: 409,
# Decode Time: 0.8218301649903879,
# Backtrace Time: 0.0002530910132918507
#
# File: 0088.wav,
# Errors: (3, 0, 1),
# WER: 57.14285714285714,
# Expected: "pickled peter picked piper picked a peck",
# actual: "picked peter a piper of a of peck",
# Steps Taken: 383,
# Decode Time: 0.7534745640004985,
# Backtrace Time: 0.00021731699234806
#
# File: 0089.wav,
# Errors: (2, 0, 0),
# WER: 66.66666666666666,
# Expected: "where's the picked",
# actual: "where's of a",
# Steps Taken: 178,
# Decode Time: 0.2954340149881318,
# Backtrace Time: 0.00011007499415427446
#
# File: 0090.wav,
# Errors: (4, 1, 0),
# WER: 100.0,
# Expected: "a pickled peck of peter",
# actual: "of picked a picked",
# Steps Taken: 204,
# Decode Time: 0.4062793109915219,
# Backtrace Time: 8.120699203573167e-05
#
# File: 0091.wav,
# Errors: (4, 1, 1),
# WER: 85.71428571428571,
# Expected: "peter the piper picked a pickled peck",
# actual: "the picked piper the peter peter a",
# Steps Taken: 392,
# Decode Time: 0.7461781100137159,
# Backtrace Time: 0.00016534802853129804
#
# File: 0092.wav,
# Errors: (6, 0, 5),
# WER: 100.0,
# Expected: "peter picked a peck of pickled peppers pickled peck the peppers",
# actual: "the peter of peck of the of peck of where's the pickled a the peck where's",
# Steps Taken: 818,
# Decode Time: 1.5637673749879468,
# Backtrace Time: 0.0004713789967354387
# File: 0093.wav,
# Errors: (1, 1, 1),
# WER: 60.0,
# Expected: "peter picked the pickled peppers",
# actual: "the peter the pickled peck",
# Steps Taken: 306,
# Decode Time: 0.5779406799993012,
# Backtrace Time: 0.00018576800357550383
#
# File: 0094.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "a peck of peppers picked piper",
# actual: "the peck of peck peppers peter piper",
# Steps Taken: 374,
# Decode Time: 0.7185706369928084,
# Backtrace Time: 0.00015042201266624033
#
# File: 0095.wav,
# Errors: (2, 0, 1),
# WER: 27.27272727272727,
# Expected: "where's the peck of pickled peppers a peck of pickled peppers",
# actual: "where's the peck of pickled where's a peck of pickled peter where's",
# Steps Taken: 588,
# Decode Time: 1.1872521819896065,
# Backtrace Time: 0.00035195701639167964
#
# File: 0096.wav,
# Errors: (2, 2, 0),
# WER: 80.0,
# Expected: "the peck of pickled peppers",
# actual: "of a of",
# Steps Taken: 383,
# Decode Time: 0.7808068350132089,
# Backtrace Time: 0.00020116599625907838
#
# File: 0097.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 357,
# Decode Time: 0.6467395329964347,
# Backtrace Time: 0.00017922997358255088
#
# File: 0098.wav,
# Errors: (0, 1, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper a peck of pickled peppers",
# Steps Taken: 588,
# Decode Time: 1.1628470419964287,
# Backtrace Time: 0.0003311660257168114
#
# File: 0099.wav,
# Errors: (1, 0, 0),
# WER: 50.0,
# Expected: "piper picked",
# actual: "piper a",
# Steps Taken: 204,
# Decode Time: 0.39389622400631197,
# Backtrace Time: 0.00011823498061858118
#
# File: 0100.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter piper picked the peppers",
# actual: "peter piper a the peppers",
# Steps Taken: 485,
# Decode Time: 1.0062517680053134,
# Backtrace Time: 0.00026919899391941726
#
# File: 0101.wav,
# Errors: (0, 3, 0),
# WER: 27.27272727272727,
# Expected: "peter piper picked a peck of pickled peppers picked a peck",
# actual: "peter piper picked peck pickled peppers picked peck",
# Steps Taken: 468,
# Decode Time: 0.9461788469925523,
# Backtrace Time: 0.00028432102408260107
#
# File: 0102.wav,
# Errors: (2, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's peck of picked peppers peter piper peck",
# Steps Taken: 366,
# Decode Time: 0.7823133759957273,
# Backtrace Time: 0.00028358999406918883
#
# File: 0103.wav,
# Errors: (3, 3, 2),
# WER: 80.0,
# Expected: "peter piper peter piper picked a peck of pickled peppers",
# actual: "picked of of of peter piper peck peck peppers",
# Steps Taken: 366,
# Decode Time: 0.7624592219945043,
# Backtrace Time: 0.00021985199418850243
#
# File: 0104.wav,
# Errors: (4, 1, 1),
# WER: 66.66666666666666,
# Expected: "pickled peppers pickled peppers peter piper picked a peck",
# actual: "picked where's picked peck where's peter piper picked peck",
# Steps Taken: 366,
# Decode Time: 0.7593874099839013,
# Backtrace Time: 0.00022583399550057948
#
# File: 0105.wav,
# Errors: (2, 2, 0),
# WER: 40.0,
# Expected: "the peck of pickled peppers peter piper picked a peck",
# actual: "the peck of picked peppers picked picked peck",
# Steps Taken: 349,
# Decode Time: 0.7232887239952106,
# Backtrace Time: 0.0002067789901047945
#
# File: 0106.wav,
# Errors: (0, 1, 2),
# WER: 50.0,
# Expected: "piper picked a peck of peppers",
# actual: "piper a peck peck peck of peppers",
# Steps Taken: 468,
# Decode Time: 0.9293442769849207,
# Backtrace Time: 0.0002725509984884411
#
# File: 0107.wav,
# Errors: (0, 0, 1),
# WER: 50.0,
# Expected: "where's peter",
# actual: "where's peter a",
# Steps Taken: 349,
# Decode Time: 0.6297014750016388,
# Backtrace Time: 0.00018659900524653494
#
# File: 0108.wav,
# Errors: (0, 1, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked peck of pickled peppers",
# Steps Taken: 528,
# Decode Time: 0.9856936500000302,
# Backtrace Time: 0.00032460500369779766
#
# File: 0109.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "pickled peppers peter piper picked",
# actual: "pickled peppers peter piper picked",
# Steps Taken: 434,
# Decode Time: 0.8090386230032891,
# Backtrace Time: 0.0002670339890755713
#
# File: 0110.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked piper",
# actual: "peter picked piper",
# Steps Taken: 332,
# Decode Time: 0.6172000119986478,
# Backtrace Time: 0.0001782249892130494
#
# File: 0111.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter piper picked",
# actual: "peter piper of peck",
# Steps Taken: 298,
# Decode Time: 0.5567325330048334,
# Backtrace Time: 0.0001023070071823895
#
# File: 0112.wav,
# Errors: (0, 2, 1),
# WER: 60.0,
# Expected: "a peck of pickled peppers",
# actual: "of pickled pickled peppers",
# Steps Taken: 323,
# Decode Time: 0.6693214999977499,
# Backtrace Time: 0.0001921159855555743
#
# File: 0113.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck",
# actual: "where's the peck",
# Steps Taken: 178,
# Decode Time: 0.28536964699742384,
# Backtrace Time: 0.00010553898755460978
#
# File: 0114.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "pickled peppers",
# actual: "pickled peppers",
# Steps Taken: 238,
# Decode Time: 0.4668479470128659,
# Backtrace Time: 7.767300121486187e-05
#
# File: 0115.wav,
# Errors: (1, 0, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked of peck of pickled peppers",
# Steps Taken: 374,
# Decode Time: 0.7264617690234445,
# Backtrace Time: 0.00017227299395017326
#
# File: 0116.wav,
# Errors: (1, 1, 0),
# WER: 28.57142857142857,
# Expected: "peter piper picked a peck of peppers",
# actual: "peter piper peter peck of peppers",
# Steps Taken: 417,
# Decode Time: 0.8101686679874547,
# Backtrace Time: 0.00024659198243170977
#
# File: 0117.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck peter piper picked",
# actual: "where's the peck peter piper picked",
# Steps Taken: 371,
# Decode Time: 0.6435049739957321,
# Backtrace Time: 0.00020206300541758537
#
# File: 0118.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter piper picked pickled peppers",
# actual: "peter piper peter pickled peppers",
# Steps Taken: 445,
# Decode Time: 0.7455591500038281,
# Backtrace Time: 0.00025823101168498397
#
# File: 0119.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck of pickled peppers",
# actual: "where's the peck of pickled peppers",
# Steps Taken: 371,
# Decode Time: 0.6251285259786528,
# Backtrace Time: 0.00020366301760077477
#
# File: 0120.wav,
# Errors: (1, 1, 0),
# WER: 25.0,
# Expected: "the peck of pickled peppers peter piper picked",
# actual: "the peck pickled peppers peter piper peter",
# Steps Taken: 491,
# Decode Time: 0.8986532699782401,
# Backtrace Time: 0.00028559399652294815
#
# File: 0121.wav,
# Errors: (1, 1, 0),
# WER: 40.0,
# Expected: "peter piper picked a peck",
# actual: "peter piper peck peck",
# Steps Taken: 323,
# Decode Time: 0.6825350419967435,
# Backtrace Time: 0.00016723701264709234
#
# File: 0122.wav,
# Errors: (2, 0, 0),
# WER: 33.33333333333333,
# Expected: "a peck of peppers peter picked",
# actual: "of peck of peppers peter peck",
# Steps Taken: 383,
# Decode Time: 0.8163231090002228,
# Backtrace Time: 0.00022314299712888896
#
# File: 0123.wav,
# Errors: (1, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the pickled peck peter picked",
# actual: "where's the pickled picked picked",
# Steps Taken: 357,
# Decode Time: 0.6913401729834732,
# Backtrace Time: 0.00019024100038222969
#
# File: 0124.wav,
# Errors: (4, 0, 1),
# WER: 62.5,
# Expected: "where's the peck of peppers peter piper picked",
# actual: "where's the peck of where's picked of of peck",
# Steps Taken: 434,
# Decode Time: 0.87411050699302,
# Backtrace Time: 0.00025277197710238397
#
# File: 0125.wav,
# Errors: (1, 1, 0),
# WER: 40.0,
# Expected: "peter piper picked pickled peppers",
# actual: "picked picked pickled peppers",
# Steps Taken: 332,
# Decode Time: 0.6856784670089837,
# Backtrace Time: 0.00017658498836681247
#
# File: 0126.wav,
# Errors: (1, 1, 0),
# WER: 40.0,
# Expected: "peter picked a pickled peppers",
# actual: "pickled a pickled peppers",
# Steps Taken: 571,
# Decode Time: 1.2488675130007323,
# Backtrace Time: 0.00030479399720206857
#
# File: 0127.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter pickled a peck piper",
# actual: "peter pickled of peck piper",
# Steps Taken: 511,
# Decode Time: 1.0769679640070535,
# Backtrace Time: 0.0002812670136336237
# File: 0128.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "where's piper pickled picked the piper",
# actual: "where's piper of pickled a the piper",
# Steps Taken: 494,
# Decode Time: 0.9128688880009577,
# Backtrace Time: 0.0002815660263877362
#
# File: 0129.wav,
# Errors: (2, 1, 2),
# WER: 62.5,
# Expected: "picked of piper peter peppers where's peter piper",
# actual: "a piper of peter peck where's where's peter piper",
# Steps Taken: 562,
# Decode Time: 1.1484076140040997,
# Backtrace Time: 0.00031150502036325634
#
# File: 0130.wav,
# Errors: (3, 0, 2),
# WER: 83.33333333333334,
# Expected: "peppers picked picked pickled of pickled",
# actual: "the where's a a pickled of pickled a",
# Steps Taken: 648,
# Decode Time: 1.3558835469884798,
# Backtrace Time: 0.0003325610014144331
#
# File: 0131.wav,
# Errors: (2, 1, 1),
# WER: 44.44444444444444,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's peck of picked of peppers picked piper picked",
# Steps Taken: 537,
# Decode Time: 1.0992526060144883,
# Backtrace Time: 0.00031493502319790423
#
# File: 0132.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 255,
# Decode Time: 0.45319119599298574,
# Backtrace Time: 0.00014223202015273273
#
# File: 0133.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "where's the peck peter piper picked",
# actual: "where's the peck peter peck picked",
# Steps Taken: 426,
# Decode Time: 0.8111536749929655,
# Backtrace Time: 0.0002393100003246218
#
# File: 0134.wav,
# Errors: (2, 0, 0),
# WER: 25.0,
# Expected: "picked a peck of pickled peppers where's peter",
# actual: "picked of peck of pickled where's where's peter",
# Steps Taken: 665,
# Decode Time: 1.4290994649927597,
# Backtrace Time: 0.0003416840045247227
#
# File: 0135.wav,
# Errors: (2, 0, 1),
# WER: 75.0,
# Expected: "peter pickled the peppers",
# actual: "peter picked the of where's",
# Steps Taken: 315,
# Decode Time: 0.6203438880038448,
# Backtrace Time: 0.00017608801135793328
#
# File: 0136.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "where's the peppers peter pickled",
# actual: "where's the where's peter pickled",
# Steps Taken: 349,
# Decode Time: 0.6330007570213638,
# Backtrace Time: 0.00013148901052773
#
# File: 0137.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "piper picked the peck",
# actual: "piper of a the peck",
# Steps Taken: 366,
# Decode Time: 0.7417297540232539,
# Backtrace Time: 0.00010688402107916772
#
# File: 0138.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "peter picked the pickled peppers",
# actual: "the picked the pickled peppers",
# Steps Taken: 289,
# Decode Time: 0.5874385650095064,
# Backtrace Time: 0.00016699801199138165
#
# File: 0139.wav,
# Errors: (1, 2, 0),
# WER: 33.33333333333333,
# Expected: "where's the pickled peppers of the peck piper picked",
# actual: "where's pickled where's of peck piper picked",
# Steps Taken: 443,
# Decode Time: 0.8511111669940874,
# Backtrace Time: 0.00026003801031038165
#
# File: 0140.wav,
# Errors: (2, 0, 2),
# WER: 100.0,
# Expected: "peter piper pickled peppers",
# actual: "peck a picked of pickled peppers",
# Steps Taken: 296,
# Decode Time: 0.6305852810037322,
# Backtrace Time: 0.00018362500122748315
#
# File: 0141.wav,
# Errors: (4, 1, 0),
# WER: 71.42857142857143,
# Expected: "peter pickled a peck of pickled peppers",
# actual: "peppers the the peck of where's",
# Steps Taken: 445,
# Decode Time: 0.971966239012545,
# Backtrace Time: 0.000240408000536263
#
# File: 0142.wav,
# Errors: (2, 0, 1),
# WER: 37.5,
# Expected: "where's the peck of peppers peter piper pickled",
# actual: "where's the peck of of picked piper of pickled",
# Steps Taken: 417,
# Decode Time: 0.807997146010166,
# Backtrace Time: 0.000256211991654709
#
# File: 0143.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "picked peppers peter piper pickled",
# actual: "picked peppers peter piper pickled",
# Steps Taken: 361,
# Decode Time: 0.7184059800056275,
# Backtrace Time: 0.00020122498972341418
#
# File: 0144.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "where's the peter piper pickled peppers",
# actual: "where's the peter piper pickled where's",
# Steps Taken: 333,
# Decode Time: 0.6017612830037251,
# Backtrace Time: 0.00018233200535178185
#
# File: 0145.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peppers pickled of peck the where's",
# actual: "peppers pickled of piper the where's",
# Steps Taken: 357,
# Decode Time: 0.6348690460145008,
# Backtrace Time: 0.0001965870033018291
#
# File: 0146.wav,
# Errors: (0, 1, 0),
# WER: 25.0,
# Expected: "piper pickled a peck",
# actual: "piper pickled peck",
# Steps Taken: 264,
# Decode Time: 0.4863399309979286,
# Backtrace Time: 9.27259970922023e-05
#
# File: 0147.wav,
# Errors: (0, 0, 2),
# WER: 66.66666666666666,
# Expected: "peter picked piper",
# actual: "peter of picked piper of",
# Steps Taken: 229,
# Decode Time: 0.4130964289943222,
# Backtrace Time: 8.254600106738508e-05
#
# File: 0148.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the pickled peter piper",
# actual: "where's the pickled peter piper",
# Steps Taken: 349,
# Decode Time: 0.5258554030151572,
# Backtrace Time: 0.00011952401837334037
#
# File: 0149.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "a peck of peter peppers",
# actual: "of peck of peter peppers",
# Steps Taken: 272,
# Decode Time: 0.4631367429974489,
# Backtrace Time: 9.890901856124401e-05
#
# File: 0150.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper peter piper peter piper picked",
# actual: "piper peter piper peter piper picked",
# Steps Taken: 741,
# Decode Time: 1.4825561219768133,
# Backtrace Time: 0.00036926098982803524
#
# File: 0151.wav,
# Errors: (3, 0, 2),
# WER: 83.33333333333334,
# Expected: "of the pickled peppers piper picked",
# actual: "of picked pickled picked where's piper peck a",
# Steps Taken: 511,
# Decode Time: 1.1077472540200688,
# Backtrace Time: 0.00030441698618233204
#
# File: 0152.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 434,
# Decode Time: 0.7367693870037328,
# Backtrace Time: 0.00023843301460146904
#
# File: 0153.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "peppers pickled piper",
# actual: "peck where's pickled piper",
# Steps Taken: 417,
# Decode Time: 0.8195251119905151,
# Backtrace Time: 0.00023597897961735725
#
# File: 0154.wav,
# Errors: (3, 2, 1),
# WER: 54.54545454545454,
# Expected: "where's the peck of peter piper pickled peppers peter piper picked",
# actual: "where's pickled peter piper peck picked where's peter piper picked",
# Steps Taken: 605,
# Decode Time: 1.0847691300150473,
# Backtrace Time: 0.00037062299088574946
#
# File: 0155.wav,
# Errors: (1, 1, 1),
# WER: 30.0,
# Expected: "peter piper pickled peppers picked a peck where's the peck",
# actual: "the of piper pickled peppers picked peck where's the peck",
# Steps Taken: 408,
# Decode Time: 0.7815984879853204,
# Backtrace Time: 0.00026867800625041127
#
# File: 0156.wav,
# Errors: (2, 0, 0),
# WER: 25.0,
# Expected: "pickled a peck piper peppers picked where's peter",
# actual: "pickled the of piper peppers picked where's peter",
# Steps Taken: 398,
# Decode Time: 0.6855713209952228,
# Backtrace Time: 0.0002398500218987465
#
# File: 0157.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked peppers",
# actual: "peter picked peppers",
# Steps Taken: 222,
# Decode Time: 0.42048320901812986,
# Backtrace Time: 0.0001292990054935217
#
# File: 0158.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's the peck of pickled peppers peter piper pickled peppers where's the picked peck",
# actual: "where's the peck of pickled peppers peter piper pickled peppers where's the picked peck",
# Steps Taken: 621,
# Decode Time: 1.1134503729990683,
# Backtrace Time: 0.0003926000208593905
#
# File: 0159.wav,
# Errors: (0, 0, 3),
# WER: 50.0,
# Expected: "pickled pickled pickled peppers peppers peck",
# actual: "the pickled pickled pickled the peppers peppers the peck",
# Steps Taken: 436,
# Decode Time: 0.831519102997845,
# Backtrace Time: 0.00033155499841086566
#
# File: 0160.wav,
# Errors: (6, 1, 3),
# WER: 58.82352941176471,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled of picked peck of pickled of where's where's the peck of pickled picked the of picked of a",
# Steps Taken: 656,
# Decode Time: 1.371424251992721,
# Backtrace Time: 0.00042307499097660184
# File: 0161.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "peter picked a peck of peppers",
# actual: "the of picked of peck of where's",
# Steps Taken: 357,
# Decode Time: 0.79606498600333,
# Backtrace Time: 0.0002234900020994246
#
# File: 0162.wav,
# Errors: (2, 0, 0),
# WER: 33.33333333333333,
# Expected: "where's the peppers peter piper picked",
# actual: "where's the peppers pickled piper a",
# Steps Taken: 349,
# Decode Time: 0.6629565159964841,
# Backtrace Time: 0.00021040698629803956
#
# File: 0163.wav,
# Errors: (3, 0, 0),
# WER: 42.857142857142854,
# Expected: "a peck of pickled peppers peter picked",
# actual: "of peck of pickled peppers pickled a",
# Steps Taken: 357,
# Decode Time: 0.7641038779984228,
# Backtrace Time: 0.00017868500435724854
#
# File: 0164.wav,
# Errors: (3, 0, 1),
# WER: 80.0,
# Expected: "pickled peppers picked peter piper",
# actual: "the of the picked picked piper",
# Steps Taken: 272,
# Decode Time: 0.5321426080190577,
# Backtrace Time: 0.00015664700185880065
#
# File: 0165.wav,
# Errors: (2, 2, 3),
# WER: 87.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the the piper picked of pickled pickled picked where's",
# Steps Taken: 989,
# Decode Time: 2.0812869599903934,
# Backtrace Time: 0.0005033009801991284
#
# File: 0166.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter",
# actual: "peter",
# Steps Taken: 238,
# Decode Time: 0.48078040801919997,
# Backtrace Time: 0.00011975999223068357
#
# File: 0167.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper",
# actual: "piper",
# Steps Taken: 178,
# Decode Time: 0.3215267500199843,
# Backtrace Time: 5.5723998229950666e-05
#
# File: 0168.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peck",
# actual: "peck",
# Steps Taken: 170,
# Decode Time: 0.34691169299185276,
# Backtrace Time: 5.517099634744227e-05
#
# File: 0169.wav,
# Errors: (1, 0, 0),
# WER: 100.0,
# Expected: "pickled",
# actual: "peck",
# Steps Taken: 153,
# Decode Time: 0.30660426800022833,
# Backtrace Time: 5.245499778538942e-05
#
# File: 0170.wav,
# Errors: (1, 0, 0),
# WER: 100.0,
# Expected: "peppers",
# actual: "the",
# Steps Taken: 204,
# Decode Time: 0.40103750201524235,
# Backtrace Time: 5.772800068370998e-05
#
# File: 0171.wav,
# Errors: (2, 3, 2),
# WER: 87.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the of of peter pickled peter peppers",
# Steps Taken: 361,
# Decode Time: 0.7396160459902603,
# Backtrace Time: 0.0002206290082540363
#
# File: 0172.wav,
# Errors: (3, 2, 1),
# WER: 66.66666666666666,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of pickled peter peter peter pickled the",
# Steps Taken: 454,
# Decode Time: 0.9210912770067807,
# Backtrace Time: 0.0002926239976659417
#
# File: 0173.wav,
# Errors: (5, 0, 5),
# WER: 125.0,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "the of of of of pickled of of peter of of of the",
# Steps Taken: 454,
# Decode Time: 0.9755484719935339,
# Backtrace Time: 0.00027692399453371763
#
# File: 0174.wav,
# Errors: (5, 1, 3),
# WER: 100.0,
# Expected: "peter piper picked a peck where's the pickled peppers",
# actual: "the of of of pickled peck where's pickled peter of where's",
# Steps Taken: 482,
# Decode Time: 0.9847615920007229,
# Backtrace Time: 0.0003188920090906322
#
# File: 0175.wav,
# Errors: (6, 1, 2),
# WER: 90.0,
# Expected: "peter piper picked pickled peppers a peck of pickled peppers",
# actual: "the of of of pickled pickled peppers of piper where's pickled",
# Steps Taken: 510,
# Decode Time: 1.0760156100150198,
# Backtrace Time: 0.00032781600020825863
#
# File: 0176.wav,
# Errors: (4, 0, 1),
# WER: 100.0,
# Expected: "a peck of pickled peppers",
# actual: "pickled of the of of where's",
# Steps Taken: 315,
# Decode Time: 0.6580258650064934,
# Backtrace Time: 0.00016802799655124545
#
# File: 0177.wav,
# Errors: (2, 0, 2),
# WER: 200.0,
# Expected: "picked peppers",
# actual: "the the of of",
# Steps Taken: 187,
# Decode Time: 0.36049806597293355,
# Backtrace Time: 9.260998922400177e-05
#
# File: 0178.wav,
# Errors: (3, 0, 4),
# WER: 233.33333333333334,
# Expected: "peter picked peppers",
# actual: "of the of a the of of",
# Steps Taken: 204,
# Decode Time: 0.38286493299528956,
# Backtrace Time: 8.169998181983829e-05
#
# File: 0179.wav,
# Errors: (5, 0, 4),
# WER: 180.0,
# Expected: "peter piper picked pickled peppers",
# actual: "the of of of a of a of where's",
# Steps Taken: 315,
# Decode Time: 0.6123478359950241,
# Backtrace Time: 0.00010265700984746218
#
# File: 0180.wav,
# Errors: (6, 0, 2),
# WER: 88.88888888888889,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of peter picked of where's the of of of picked",
# Steps Taken: 417,
# Decode Time: 0.8424171380174812,
# Backtrace Time: 0.0002878099912777543
#
# File: 0181.wav,
# Errors: (5, 1, 1),
# WER: 41.17647058823529,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peck piper peck peck of peck of peppers where's the peck of peck peppers peter piper peck",
# Steps Taken: 648,
# Decode Time: 1.2927108529838733,
# Backtrace Time: 0.00038949199370108545
#
# File: 0182.wav,
# Errors: (6, 1, 0),
# WER: 41.17647058823529,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled of picked peck peck of peppers where's the peck of peck peppers peter peck peck",
# Steps Taken: 699,
# Decode Time: 1.4767306959838606,
# Backtrace Time: 0.000411916000302881
#
# File: 0183.wav,
# Errors: (8, 0, 1),
# WER: 52.94117647058824,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "the of of of picked peck of peck peppers where's the peck of peck piper peter of picked",
# Steps Taken: 605,
# Decode Time: 1.2439182439993601,
# Backtrace Time: 0.0003642899973783642
#
# File: 0184.wav,
# Errors: (4, 2, 2),
# WER: 47.05882352941176,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "pickled picked peck of peck of peppers where's the peck of peck of peppers peter peter picked",
# Steps Taken: 579,
# Decode Time: 1.2364405910193454,
# Backtrace Time: 0.00036277499748393893
#
# File: 0185.wav,
# Errors: (5, 1, 2),
# WER: 47.05882352941176,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peck of picked peck of peck of peppers where's the peck of peck of peppers peter peck picked",
# Steps Taken: 571,
# Decode Time: 1.1616600250126794,
# Backtrace Time: 0.00036498901317827404
#
# File: 0186.wav,
# Errors: (2, 1, 3),
# WER: 75.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the the of piper picked the a of pickled where's",
# Steps Taken: 520,
# Decode Time: 1.0287049119942822,
# Backtrace Time: 0.0003041470190510154
#
# File: 0187.wav,
# Errors: (2, 1, 1),
# WER: 66.66666666666666,
# Expected: "where's the peck of pickled peppers",
# actual: "where's a of the of peppers",
# Steps Taken: 426,
# Decode Time: 0.8035579050192609,
# Backtrace Time: 0.00024277000920847058
#
# File: 0188.wav,
# Errors: (3, 1, 1),
# WER: 83.33333333333334,
# Expected: "a peck of peppers piper picked",
# actual: "of peck where's piper of the",
# Steps Taken: 417,
# Decode Time: 0.852673034009058,
# Backtrace Time: 0.00023787200916558504
#
# File: 0189.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "where's the peck peter piper picked",
# actual: "where's the a the the piper a",
# Steps Taken: 392,
# Decode Time: 0.7299996149959043,
# Backtrace Time: 0.00020334799773991108
#
# File: 0190.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter picked pickled peppers",
# actual: "peter picked pickled peppers",
# Steps Taken: 332,
# Decode Time: 0.6564698169822805,
# Backtrace Time: 0.0001930010039359331
#
# File: 0191.wav,
# Errors: (2, 2, 0),
# WER: 50.0,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter the peck of picked peppers",
# Steps Taken: 281,
# Decode Time: 0.5989165400096681,
# Backtrace Time: 0.00012077199062332511
#
# File: 0192.wav,
# Errors: (2, 4, 1),
# WER: 77.77777777777779,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's of of of picked the",
# Steps Taken: 349,
# Decode Time: 0.7015070019988343,
# Backtrace Time: 0.0001376330037601292
# File: 0193.wav,
# Errors: (5, 0, 1),
# WER: 120.0,
# Expected: "piper peter picked pickled peppers",
# actual: "peck the the a the piper",
# Steps Taken: 298,
# Decode Time: 0.5970189590007067,
# Backtrace Time: 0.00015688699204474688
#
# File: 0194.wav,
# Errors: (4, 0, 4),
# WER: 133.33333333333331,
# Expected: "where's peter piper pickled peppers picked",
# actual: "the where's of of of the where's of picked the",
# Steps Taken: 340,
# Decode Time: 0.683047725004144,
# Backtrace Time: 0.0001433180004823953
#
# File: 0195.wav,
# Errors: (5, 0, 2),
# WER: 87.5,
# Expected: "picked peppers peter piper picked where's the peck",
# actual: "picked the where's the of of a the the peck",
# Steps Taken: 417,
# Decode Time: 0.8609939070011023,
# Backtrace Time: 0.0002641039900481701
#
# File: 0196.wav,
# Errors: (2, 2, 1),
# WER: 62.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "the of piper picked pickled pickled peppers",
# Steps Taken: 409,
# Decode Time: 0.7739679799997248,
# Backtrace Time: 0.0002634850097820163
#
# File: 0197.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter picked pickled peppers",
# actual: "a of picked pickled peppers",
# Steps Taken: 255,
# Decode Time: 0.5070423440192826,
# Backtrace Time: 0.0001545650011394173
#
# File: 0198.wav,
# Errors: (1, 2, 1),
# WER: 50.0,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "of pickled pickled peppers picked piper picked",
# Steps Taken: 468,
# Decode Time: 0.9206547549983952,
# Backtrace Time: 0.00029421699582599103
#
# File: 0199.wav,
# Errors: (1, 0, 0),
# WER: 20.0,
# Expected: "pickled peppers picked piper peter",
# actual: "peck peppers picked piper peter",
# Steps Taken: 332,
# Decode Time: 0.6259070399974007,
# Backtrace Time: 0.0001780540042091161
#
# File: 0200.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "piper peter picked peppers",
# actual: "piper peter picked peppers",
# Steps Taken: 323,
# Decode Time: 0.6584637119958643,
# Backtrace Time: 0.00010531401494517922
#
# File: 0201.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "peter picked a peck of peppers",
# actual: "peter picked of peck of peppers",
# Steps Taken: 485,
# Decode Time: 0.9464436099806335,
# Backtrace Time: 0.00028213398763909936
#
# File: 0202.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter the peppers pickled",
# actual: "where's peter the peppers pickled",
# Steps Taken: 434,
# Decode Time: 0.7497255649941508,
# Backtrace Time: 0.00026294999406673014
#
# File: 0203.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "the picked peter piper",
# actual: "the picked peter piper",
# Steps Taken: 264,
# Decode Time: 0.42534824399626814,
# Backtrace Time: 0.00015621600323356688
#
# File: 0204.wav,
# Errors: (0, 1, 0),
# WER: 33.33333333333333,
# Expected: "where's the peter",
# actual: "where's peter",
# Steps Taken: 178,
# Decode Time: 0.25083662001998164,
# Backtrace Time: 6.454001413658261e-05
#
# File: 0205.wav,
# Errors: (0, 1, 0),
# WER: 11.11111111111111,
# Expected: "peppers peppers peppers peppers peppers peppers peppers peppers peppers",
# actual: "peppers peppers peppers peppers peppers peppers peppers peppers",
# Steps Taken: 528,
# Decode Time: 1.050298528978601,
# Backtrace Time: 0.0003301550168544054
#
# File: 0206.wav,
# Errors: (1, 0, 0),
# WER: 12.5,
# Expected: "peter piper picked a peck of pickled peppers",
# actual: "peter piper picked of peck of pickled peppers",
# Steps Taken: 579,
# Decode Time: 1.11882302101003,
# Backtrace Time: 0.0003299280069768429
#
# File: 0207.wav,
# Errors: (1, 0, 0),
# WER: 11.11111111111111,
# Expected: "where's the peck of pickled peppers peter piper picked",
# actual: "where's pickled peck of pickled peppers peter piper picked",
# Steps Taken: 750,
# Decode Time: 1.4117106670164503,
# Backtrace Time: 0.0004106030100956559
#
# File: 0208.wav,
# Errors: (3, 0, 4),
# WER: 140.0,
# Expected: "peter piper picked pickled peppers",
# actual: "the peck a a picked peck pickled of where's",
# Steps Taken: 588,
# Decode Time: 1.2395818380173296,
# Backtrace Time: 0.0003370349877513945
#
# File: 0209.wav,
# Errors: (3, 0, 3),
# WER: 100.0,
# Expected: "peck pickled peppers peter piper picked",
# actual: "picked peck pickled peck where's picked picked of peck",
# Steps Taken: 571,
# Decode Time: 1.1861664269817993,
# Backtrace Time: 0.0003300250100437552
#
# File: 0210.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "peter piper picked peck pickled peppers",
# actual: "picked piper picked peck pickled peck where's",
# Steps Taken: 579,
# Decode Time: 1.1804105330083985,
# Backtrace Time: 0.0003299910167697817
#
# File: 0211.wav,
# Errors: (2, 1, 4),
# WER: 116.66666666666667,
# Expected: "peck pickled peppers peter piper picked",
# actual: "peck a pickled of where's picked peck a a",
# Steps Taken: 520,
# Decode Time: 1.0736884330108296,
# Backtrace Time: 0.00030620599864050746
#
# File: 0212.wav,
# Errors: (3, 0, 6),
# WER: 150.0,
# Expected: "peter piper picked peck pickled peppers",
# actual: "the of peck a peck picked the peck of pickled peck where's",
# Steps Taken: 588,
# Decode Time: 1.2736896419955883,
# Backtrace Time: 0.0003461150045040995
#
# File: 0213.wav,
# Errors: (0, 1, 0),
# WER: 16.666666666666664,
# Expected: "peter picked a peck of peppers",
# actual: "peter picked peck of peppers",
# Steps Taken: 289,
# Decode Time: 0.5693999310024083,
# Backtrace Time: 0.00016884098295122385
#
# File: 0214.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter pickled peter pickled peppers peppers peppers",
# actual: "peter pickled peter pickled peppers peppers peppers",
# Steps Taken: 374,
# Decode Time: 0.6812998279929161,
# Backtrace Time: 0.00019953999435529113
#
# File: 0215.wav,
# Errors: (0, 0, 1),
# WER: 20.0,
# Expected: "peter peter where's the piper",
# actual: "peter of peter where's the piper",
# Steps Taken: 221,
# Decode Time: 0.3395055680011865,
# Backtrace Time: 0.0001362570037599653
#
# File: 0216.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "pickled picked pickled picked",
# actual: "pickled picked pickled picked",
# Steps Taken: 289,
# Decode Time: 0.5459921740111895,
# Backtrace Time: 0.00012981402687728405
#
# File: 0217.wav,
# Errors: (0, 1, 1),
# WER: 28.57142857142857,
# Expected: "a of the of the of the",
# actual: "of the picked of the of the",
# Steps Taken: 374,
# Decode Time: 0.7594563339953311,
# Backtrace Time: 0.00018998899031430483
#
# File: 0218.wav,
# Errors: (1, 0, 1),
# WER: 50.0,
# Expected: "peter picked pickled peppers",
# actual: "peter pickled picked of peppers",
# Steps Taken: 357,
# Decode Time: 0.7365097090078052,
# Backtrace Time: 0.00022329000057652593
#
# File: 0219.wav,
# Errors: (2, 0, 0),
# WER: 50.0,
# Expected: "piper picked a peck",
# actual: "piper picked of of",
# Steps Taken: 374,
# Decode Time: 0.7339266820054036,
# Backtrace Time: 0.00020114501239731908
#
# File: 0220.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "where's peter piper",
# actual: "where's peter piper",
# Steps Taken: 255,
# Decode Time: 0.4048543550015893,
# Backtrace Time: 0.00010763699538074434
#
# File: 0221.wav,
# Errors: (2, 0, 0),
# WER: 66.66666666666666,
# Expected: "pickled peppers picked",
# actual: "the peppers of",
# Steps Taken: 264,
# Decode Time: 0.5284519020060543,
# Backtrace Time: 0.0001537380157969892
#
# File: 0222.wav,
# Errors: (2, 0, 1),
# WER: 75.0,
# Expected: "a peck of peppers",
# actual: "of peck of of where's",
# Steps Taken: 246,
# Decode Time: 0.44921469601104036,
# Backtrace Time: 9.574199793860316e-05
#
# File: 0223.wav,
# Errors: (1, 0, 0),
# WER: 16.666666666666664,
# Expected: "pickled peppers pickled peter peck picked",
# actual: "pickled peppers pickled peter peck peck",
# Steps Taken: 537,
# Decode Time: 1.0612039339903276,
# Backtrace Time: 0.00029906799318268895
#
# File: 0224.wav,
# Errors: (0, 1, 0),
# WER: 20.0,
# Expected: "piper peck of peppers peter",
# actual: "piper peck peppers peter",
# Steps Taken: 400,
# Decode Time: 0.8067791490175296,
# Backtrace Time: 0.00022941798670217395
#
# File: 0225.wav,
# Errors: (1, 1, 1),
# WER: 50.0,
# Expected: "peppers peppers picked of peter pickled",
# actual: "peppers peck where's picked peter pickled",
# Steps Taken: 332,
# Decode Time: 0.6571941029978916,
# Backtrace Time: 0.0002062940038740635
#
# File: 0226.wav,
# Errors: (0, 0, 1),
# WER: 20.0,
# Expected: "peter peter peck of piper",
# actual: "peter peter peck of piper a",
# Steps Taken: 281,
# Decode Time: 0.5405972320004366,
# Backtrace Time: 0.0001633289793971926
# File: 0227.wav,
# Errors: (2, 0, 1),
# WER: 50.0,
# Expected: "peppers picked picked of piper pickled",
# actual: "where's picked picked of peck of pickled",
# Steps Taken: 443,
# Decode Time: 0.8868574760272168,
# Backtrace Time: 0.0002757250040303916
#
# File: 0228.wav,
# Errors: (3, 1, 1),
# WER: 62.5,
# Expected: "peck peppers pickled the picked pickled the peter",
# actual: "peck of where's pickled of peck pickled peter",
# Steps Taken: 468,
# Decode Time: 0.9329883419850376,
# Backtrace Time: 0.0002927039749920368
#
# File: 0229.wav,
# Errors: (2, 1, 0),
# WER: 25.0,
# Expected: "piper pickled a piper of peppers picked peter peter pickled peppers peter",
# actual: "pickled of piper of where's picked peter peter pickled peppers peter",
# Steps Taken: 648,
# Decode Time: 1.3053329100075644,
# Backtrace Time: 0.0003934809938073158
#
# File: 0230.wav,
# Errors: (2, 0, 0),
# WER: 40.0,
# Expected: "pickled a peck piper of",
# actual: "pickled of where's piper of",
# Steps Taken: 468,
# Decode Time: 0.9944181140162982,
# Backtrace Time: 0.0002564460155554116
#
# File: 0231.wav,
# Errors: (0, 2, 0),
# WER: 11.76470588235294,
# Expected: "peter piper picked a peck of pickled peppers where's the peck of pickled peppers peter piper picked",
# actual: "peter piper picked peck of pickled peppers where's the peck pickled peppers peter piper picked",
# Steps Taken: 793,
# Decode Time: 1.5171409010072239,
# Backtrace Time: 0.0004760220181196928
#
# File: 0232.wav,
# Errors: (0, 1, 0),
# WER: 5.88235294117647,
# Expected: "piper peter picked a peck of pickled peppers where's the peck of pickled peppers piper peter picked",
# actual: "piper peter picked peck of pickled peppers where's the peck of pickled peppers piper peter picked",
# Steps Taken: 810,
# Decode Time: 1.4860021559870802,
# Backtrace Time: 0.0005002279940526932
#
# File: 0233.wav,
# Errors: (1, 1, 0),
# WER: 13.333333333333334,
# Expected: "peter picked a peck of pickled peppers where's the peck of pickled peppers peter picked",
# actual: "peter picked of peck pickled peppers where's the peck of pickled peppers peter picked",
# Steps Taken: 767,
# Decode Time: 1.456768705014838,
# Backtrace Time: 0.00043399998685345054
#
# File: 0234.wav,
# Errors: (1, 0, 0),
# WER: 12.5,
# Expected: "a peck of pickled peppers peter piper picked",
# actual: "of peck of pickled peppers peter piper picked",
# Steps Taken: 443,
# Decode Time: 0.8974418169818819,
# Backtrace Time: 0.0002646770153660327
#
# File: 0235.wav,
# Errors: (0, 0, 0),
# WER: 0.0,
# Expected: "peter peppers picked pickled piper where's the peck of pickled piper",
# actual: "peter peppers picked pickled piper where's the peck of pickled piper",
# Steps Taken: 605,
# Decode Time: 1.028794965997804,
# Backtrace Time: 0.0003737189981620759
#
# File: 0236.wav,
# Errors: (1, 0, 1),
# WER: 33.33333333333333,
# Expected: "where's the peck peter piper picked",
# actual: "where's of peck peter of piper picked",
# Steps Taken: 408,
# Decode Time: 0.7285661110072397,
# Backtrace Time: 0.00025743100559338927
#
# File: 0237.wav,
# Errors: (3, 0, 1),
# WER: 66.66666666666666,
# Expected: "a peck of picked pickled peppers",
# actual: "of picked of picked pickled of where's",
# Steps Taken: 361,
# Decode Time: 0.7156287849938963,
# Backtrace Time: 0.00020560401026159525
#
# File: 0238.wav,
# Errors: (1, 0, 1),
# WER: 66.66666666666666,
# Expected: "where's peter piper",
# actual: "where's a of piper",
# Steps Taken: 306,
# Decode Time: 0.5164289780077524,
# Backtrace Time: 0.0001512560120318085
#
# File: 0239.wav,
# Errors: (6, 0, 0),
# WER: 75.0,
# Expected: "a peck of pickled peppers picked peter piper",
# actual: "of picked of a where's a peppers piper",
# Steps Taken: 491,
# Decode Time: 0.9616025769792031,
# Backtrace Time: 0.00027314500766806304
#
# File: 0240.wav,
# Errors: (1, 1, 0),
# WER: 33.33333333333333,
# Expected: "a peck of piper pickled peter",
# actual: "of of piper pickled peter",
# Steps Taken: 389,
# Decode Time: 0.7249104130023625,
# Backtrace Time: 0.00019717399845831096
#
#
# Done

# %%
print("Done")
#f = create_wfst(bigram)
#from subprocess import check_call
#from IPython.display import Image
#f.draw('tmp.dot', portrait=True)
#check_call(['dot','-Tpng','-Gdpi=200','tmp.dot','-o','tmp.png'])
#Image(filename='tmp.png')
# Out:
# Done

# %%
#
